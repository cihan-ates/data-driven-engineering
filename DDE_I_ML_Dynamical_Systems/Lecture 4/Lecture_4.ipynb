# %% [markdown]
# #Active Session II: Classification

# %% [markdown]
# #Important Note
#
# Lecture notes and notebooks must not be copied and/or distributed without the express permission of ITS.

# %% [markdown]
# #1. Problem Definition: Probe into the Data
#
# In this dataset, we will look into the relationship between airfoil design and its relationship with noise generation.
#
# This NASA data set was obtained from a series of aerodynamic and acoustic tests of two and three-dimensional airfoil blade sections conducted in an anechoic wind tunnel. It comprises different size NACA 0012 airfoils at various wind tunnel speeds and angles of attack. The span of the airfoil and the observer position were the same in all of the experiments.
#
# Attribute Information:
#
# This problem has the following inputs:
# 1. Frequency, in Hertzs.
# 2. Angle of attack, in degrees.
# 3. Chord length, in meters.
# 4. Free-stream velocity, in meters per second.
# 5. Suction side displacement thickness, in meters.
#
# The only output is:
# 6. Scaled sound pressure level, in decibels.

# %% [markdown]
# # 2. Preparing the enviroment
#
# Import the Python libraries that we will need to (i) load the data, (ii) analyze it, (iii) create our model, (iv) process the results.

# %%
#Importing the necessary libraries
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()
import matplotlib as mpl

# %%
# Data Preparation
from sklearn import preprocessing as pp
from scipy.stats import pearsonr
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import log_loss
from sklearn.metrics import precision_recall_curve, average_precision_score
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.metrics import confusion_matrix, classification_report

# %%
# ML Algorithms to be used
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import RandomForestClassifier
import lightgbm as LGBMClassifier

#If you are working on local machine:
# pip install lightgbm

# %% [markdown]
# # 3. Pre-processing

# %% [markdown]
# ## Loading the Data
#
# We need to upload the dataset to Colab enviroment. Pandas library is a practical way to load and read the data from an url. Since the data is only given as tabulated values, we need to add the name of the features as well.

# %%
# Loading the data
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00291/airfoil_self_noise.dat'
new_names = ['frequency','angle_attack','chord_length','Free-stream_velocity','displacement_thickness','sound_pressure']
data = pd.read_csv(url, names=new_names, delimiter='\t')
data.head()
# Out:
#    frequency  angle_attack  ...  displacement_thickness  sound_pressure
# 0        800           0.0  ...                0.002663         126.201
# 1       1000           0.0  ...                0.002663         125.201
# 2       1250           0.0  ...                0.002663         125.951
# 3       1600           0.0  ...                0.002663         127.591
# 4       2000           0.0  ...                0.002663         127.461
#
# [5 rows x 6 columns]

# %% [markdown]
# ## Data Exploration
# Here we will look into the statistics of the data, identify any missing values or categorical features that is needed to be further process.
#
# Let’s analyze our dataset first. Use dataset.head(n) to display top n data. You can change dataset.head(n) to dataset.sample(n) to display randomly picked data:

# %%
 data.head(5)
# Out:
#    frequency  angle_attack  ...  displacement_thickness  sound_pressure
# 0        800           0.0  ...                0.002663         126.201
# 1       1000           0.0  ...                0.002663         125.201
# 2       1250           0.0  ...                0.002663         125.951
# 3       1600           0.0  ...                0.002663         127.591
# 4       2000           0.0  ...                0.002663         127.461
#
# [5 rows x 6 columns]

# %%
data.sample(5)
# Out:
#       frequency  angle_attack  ...  displacement_thickness  sound_pressure
# 619        1250           7.2  ...                0.009092         122.428
# 1352        500           6.7  ...                0.005214         129.343
# 353        1600           4.0  ...                0.005091         125.229
# 1365       1250           6.7  ...                0.005781         132.395
# 1494       1000          15.6  ...                0.052849         119.224
#
# [5 rows x 6 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1503 entries, 0 to 1502
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   frequency               1503 non-null   int64
#  1   angle_attack            1503 non-null   float64
#  2   chord_length            1503 non-null   float64
#  3   Free-stream_velocity    1503 non-null   float64
#  4   displacement_thickness  1503 non-null   float64
#  5   sound_pressure          1503 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 70.6 KB

# %% [markdown]
# Let's look into the statistics of the data. This is usually a good starting point to have an idea obout the range of the data, its nature, as well as the missing information for different features:

# %%
data.describe()
# Out:
#           frequency  angle_attack  ...  displacement_thickness  sound_pressure
# count   1503.000000   1503.000000  ...             1503.000000     1503.000000
# mean    2886.380572      6.782302  ...                0.011140      124.835943
# std     3152.573137      5.918128  ...                0.013150        6.898657
# min      200.000000      0.000000  ...                0.000401      103.380000
# 25%      800.000000      2.000000  ...                0.002535      120.191000
# 50%     1600.000000      5.400000  ...                0.004957      125.721000
# 75%     4000.000000      9.900000  ...                0.015576      129.995500
# max    20000.000000     22.200000  ...                0.058411      140.987000
#
# [8 rows x 6 columns]

# %% [markdown]
# If not defined by the user, you can also explore the features with the following command:

# %%
data.columns
# Out:
# Index(['frequency', 'angle_attack', 'chord_length', 'Free-stream_velocity',
#        'displacement_thickness', 'sound_pressure'],
#       dtype='object')

# %% [markdown]
# It is also possible to explore individual features:

# %%
data['sound_pressure'].median()
# Out:
# 125.721

# %%
data['sound_pressure'].mean()
# Out:
# 124.83594278110434

# %% [markdown]
# ### Data Visualization
#
# Another important pre-processing step is the data visualization. Histograms are suitable for a holistic view, where we can probe into the data for each attribute.
#
# We can use hist from matplotlib for that purpose:

# %%
data.hist(bins=30, figsize=(15,15))
plt.show()

# %% [markdown]
# It is always a good exercise to look into the data visually and try to see the distributions of the features.

# %% [markdown]
# ### Identify nonnumerical values
# Some ML algorithms can not handle non-numerical values (NaN: not a number) so you may need to identify the type of the data for each feature and modify it if necessary. It is also quite common that different feature values are missing for different instances / examples so you may need to decide what to do: (i) omit the instance; (ii) replace them with the mean / median / mode of the feature; (iv) substitute them with a value of your choice.
#
# The following line counts the NaNs for each feature for us:

# %%
nanCounter = np.isnan(data).sum()
print(nanCounter)
# Out:
# frequency                 0
# angle_attack              0
# chord_length              0
# Free-stream_velocity      0
# displacement_thickness    0
# sound_pressure            0
# dtype: int64

# %% [markdown]
# The data was entirely numerical and composed of numbers. We will see in the following sessions how to handle datasets including non-numerical features in a smart way!
#
# It is also a good exercise to check the uniqueness of the dataset, that is, whether there exists values repeating at different instances:

# %%
distinctCounter = data.apply(lambda x: len(x.unique()))
print(distinctCounter)
# Out:
# frequency                   21
# angle_attack                27
# chord_length                 6
# Free-stream_velocity         4
# displacement_thickness     105
# sound_pressure            1456
# dtype: int64

# %% [markdown]
# As identified earlier, there are 1503 instances (experimental measurements). Here we realized that these experiments were planned as combinations of 5 input parameters, with unique values of 21x27x6x4x105.
#
# ### Supervised Algorithms: Preparing the Labels
#
# Supervised approach requires labelled data for the training. In this dataset, the objective function is the noise levels (classification) or noise prediction (regression), depending on the question. In both cases, we need to create a feature matrix say X and and label vector Y. We will use Y to train and test our model.

# %% [markdown]
# ### Creating the Feature Matrix and Labels

# %%
dataX = data.copy().drop(['sound_pressure'],axis=1)
dataY = data['sound_pressure'].astype(int).copy()

# %% [markdown]
# ### Modifying the label vector for classification:
#
# If we are interested in a classification problem, such as identifying the noise levels depending on the airfoil design, we can modify the measured noise levels by converting them into categorical values.
#
# Assume that we will be performing binary classification with the following criteria:
# If the noise is less than 120 dB, it is "low" and it is classified as "high" if greater than 120 dB. In this exercise, we will use '0' for 'low' and '1' as 'high'. In this scenerio, we can use Binarizer:

# %%
from sklearn.preprocessing import Binarizer
#Create an object:
transformer = Binarizer(threshold=120,copy=False)
transformer
# Out:
# Binarizer(copy=False, threshold=120)

# %%
#Transforming the data with Binarizer method:
transformer.fit_transform(dataY.values.reshape(-1, 1))

#Lets see how it changes:
dataY.head
# Out:
# <bound method NDFrame.head of 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1498    0
# 1499    0
# 1500    0
# 1501    0
# 1502    0
# Name: sound_pressure, Length: 1503, dtype: int64>

# %%
dataY.value_counts()
# Out:
# 1    1073
# 0     430
# Name: sound_pressure, dtype: int64

# %% [markdown]
# For more pre-processing options; you may check:
#
# https://scikit-learn.org/stable/modules/classes.html#module-sklearn.preprocessing

# %% [markdown]
# ### Feature Standardization: Rescaling the Data
#
# Feature engineering is an inseparable aspect of ML models. In many engineering problem, we know from our tradition that combining different features significantly simplifies the problem and help us to focus our experimental / numerical work on the correct data plane. For example, we combine characteristic length, velocity, density and viscosity as Reynolds number and "classify" the flow regime in a pipe in a quite straight-forward way. The same is true on ML algorithms. You can combine features, delete the unrelated ones and rescale the data (similar to what we do in non-dimensional analysis in engineering) to help ML algorithms to seek patterns from an unbiased perspective. In our example, number of features is already small so we do not need to perform any feature engineering. We will come back to this topic in the following weeks.
#
# For the time being, lets just see how much the features are correlated. But first, we will rescale the data. It is  important to remember that most ML algorithms work better if the data is normalized around zero; that it has a mean value of zero with a standard deviation of one. Let's try it ourselves:

# %%
#Rescaling the data
featuresToScale = dataX.columns
sX = pp.StandardScaler(copy=True)
dataX.loc[:,featuresToScale] = sX.fit_transform(dataX[featuresToScale])
#Looking into the statistics again:
dataX.describe()
# Out:
#           frequency  angle_attack  ...  Free-stream_velocity  displacement_thickness
# count  1.503000e+03  1.503000e+03  ...          1.503000e+03            1.503000e+03
# mean   2.837975e-16 -3.495393e-16  ...         -8.558246e-16            2.866045e-16
# std    1.000333e+00  1.000333e+00  ...          1.000333e+00            1.000333e+00
# min   -8.524068e-01 -1.146403e+00  ...         -1.230809e+00           -8.169263e-01
# 25%   -6.620227e-01 -8.083458e-01  ...         -7.233448e-01           -6.545613e-01
# 50%   -4.081773e-01 -2.336486e-01  ...         -7.233448e-01           -4.702979e-01
# 75%    3.533590e-01  5.269801e-01  ...          1.312935e+00            3.374462e-01
# max    5.430267e+00  2.606032e+00  ...          1.312935e+00            3.595917e+00
#
# [8 rows x 5 columns]

# %% [markdown]
# As you can see, mean value is fixed as zero with a standard deviation (std) of 1. Now let's try to visualize how correlated the data is by creating a correlation matrix.

# %%
correlationMatrix = pd.DataFrame(dataX).corr() 

f = plt.figure(figsize=(12, 6))
plt.matshow(correlationMatrix, fignum=f.number)
plt.xticks(range(dataX.shape[1]), dataX.columns, fontsize=14, rotation=75)
plt.yticks(range(dataX.shape[1]), dataX.columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.show()

# %%
#we can also simply look at the table via pandas:
correlationMatrix.style.background_gradient(cmap='viridis').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row0_col0,#T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row1_col1,#T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row2_col2,#T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row3_col3,#T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row4_col4{
#             background-color:  #fde725;
#             color:  #000000;
#         }#T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row0_col1{
#             background-color:  #453581;
#             color:  #f1f1f1;
#         }#T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row0_col2{
#             background-color:  #31688e;
#             color:  #f1f1f1;
#         }#T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row0_col3{
#             background-color:  #46307e;
#             color:  #f1f1f1;
#         }#T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row0_col4,#T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row1_col0,#T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row1_col2,#T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row2_col1,#T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row4_col3{
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }#T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row1_col3{
#             background-color:  #481769;
#             color:  #f1f1f1;
#         }#T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row1_col4{
#             background-color:  #7ad151;
#             color:  #000000;
#         }#T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row2_col0{
#             background-color:  #3f4788;
#             color:  #f1f1f1;
#         }#T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row2_col3,#T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row2_col4{
#             background-color:  #440256;
#             color:  #f1f1f1;
#         }#T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row3_col0{
#             background-color:  #32648e;
#             color:  #f1f1f1;
#         }#T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row3_col1{
#             background-color:  #2c718e;
#             color:  #f1f1f1;
#         }#T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row3_col2{
#             background-color:  #30698e;
#             color:  #f1f1f1;
#         }#T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row3_col4{
#             background-color:  #423f85;
#             color:  #f1f1f1;
#         }#T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row4_col0{
#             background-color:  #470d60;
#             color:  #f1f1f1;
#         }#T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row4_col1{
#             background-color:  #93d741;
#             color:  #000000;
#         }#T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row4_col2{
#             background-color:  #424086;
#             color:  #f1f1f1;
#         }</style><table id="T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002" class="dataframe"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >frequency</th>        <th class="col_heading level0 col1" >angle_attack</th>        <th class="col_heading level0 col2" >chord_length</th>        <th class="col_heading level0 col3" >Free-stream_velocity</th>        <th class="col_heading level0 col4" >displacement_thickness</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002level0_row0" class="row_heading level0 row0" >frequency</th>
#                         <td id="T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row0_col1" class="data row0 col1" >-0.27</td>
#                         <td id="T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row0_col2" class="data row0 col2" >-0.00</td>
#                         <td id="T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row0_col3" class="data row0 col3" >0.13</td>
#                         <td id="T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row0_col4" class="data row0 col4" >-0.23</td>
#             </tr>
#             <tr>
#                         <th id="T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002level0_row1" class="row_heading level0 row1" >angle_attack</th>
#                         <td id="T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row1_col0" class="data row1 col0" >-0.27</td>
#                         <td id="T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row1_col2" class="data row1 col2" >-0.50</td>
#                         <td id="T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row1_col3" class="data row1 col3" >0.06</td>
#                         <td id="T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row1_col4" class="data row1 col4" >0.75</td>
#             </tr>
#             <tr>
#                         <th id="T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002level0_row2" class="row_heading level0 row2" >chord_length</th>
#                         <td id="T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row2_col0" class="data row2 col0" >-0.00</td>
#                         <td id="T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row2_col1" class="data row2 col1" >-0.50</td>
#                         <td id="T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row2_col3" class="data row2 col3" >0.00</td>
#                         <td id="T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row2_col4" class="data row2 col4" >-0.22</td>
#             </tr>
#             <tr>
#                         <th id="T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002level0_row3" class="row_heading level0 row3" >Free-stream_velocity</th>
#                         <td id="T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row3_col0" class="data row3 col0" >0.13</td>
#                         <td id="T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row3_col1" class="data row3 col1" >0.06</td>
#                         <td id="T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row3_col2" class="data row3 col2" >0.00</td>
#                         <td id="T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row3_col3" class="data row3 col3" >1.00</td>
#                         <td id="T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row3_col4" class="data row3 col4" >-0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002level0_row4" class="row_heading level0 row4" >displacement_thickness</th>
#                         <td id="T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row4_col0" class="data row4 col0" >-0.23</td>
#                         <td id="T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row4_col1" class="data row4 col1" >0.75</td>
#                         <td id="T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row4_col2" class="data row4 col2" >-0.22</td>
#                         <td id="T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row4_col3" class="data row4 col3" >-0.00</td>
#                         <td id="T_e5a63c0a_46cb_11ec_b71f_0242ac1c0002row4_col4" class="data row4 col4" >1.00</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# What do these numbers mean?
#
# When it is close to 1, it means that there is a strong positive correlation; At the other extreme; –1, it implies that there is a strong negative correlation. For more:
#
# https://en.wikipedia.org/wiki/Correlation_and_dependence

# %% [markdown]
# ## Preparing the Dataset for Model
#
# We need to divide our entire dataset into fractions so that we have a training set
# from which the machine learning algorithm learns. We also need another set to test the predictions of the ML algorithm. There is no golden rule here: you need to consider the size of your entire dataset. Sometimes 5% is more than enough, sometimes we need to divide 1/3 to have enough test samples.
#
# In our current examples, number of cases is quite low for a ML project. Therefore, lets leave sufficient number of test cases:

# %%
X_train, X_test, y_train, y_test = train_test_split(dataX,
dataY, test_size=0.25,
random_state=2020, stratify=dataY)

# %% [markdown]
# Here we have frozen the randomness to make the results reproducible. Otherwise, the results would change at every run.

# %% [markdown]
# ## Cross-Validation
# Another rule of thumb is to split
# the training set into a sub-training sets and a validation set before seeing its true performance on the test set (25% of the dataset reserved above). This policy is called k-fold cross-validation. The training data is divided into k fractions, trained over (k-1) fractions and tested on the k_th. Here the idea is to increase the generalization of the model as much as possible.

# %%
k_fold = StratifiedKFold(n_splits=5, shuffle=True, random_state=2020)

# %% [markdown]
# ## How to calculate the performance?
# In any supervised approach, we need to select a cost function to compare ML predictions with the true values (labels). The
# ML algorithm will minimize the cost function by changing its fitting parameters. You should spend some time to define what could be the best cost function for my dataset and my objective.
#
# In our case, we are dealing with binary classification: so lets try binary classification log loss. You may see the following links for further information:
#
# https://en.wikipedia.org/wiki/Cross_entropy
#
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.log_loss.html

# %% [markdown]
# # ML 101: Logistic Regression
#
# See the lecture notes for the model. Here is a review:
#
# https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression

# %%
# Hyperparameters:
penalty = 'l2'
C = 1.0 #regularization strength. The smaller the value, the stronger the regularization.
random_state = 2021
solver = 'liblinear' # For small datasets, it is good.
logReg = LogisticRegression(penalty=penalty, C=C,random_state=random_state, solver=solver)

# %%
# Model Training:
#-----------------------------------------------------------------------------
#Lists for storing scores
trainingScores = []
cvScores = []

#DataFrame is a 2-dimensional labeled data structure. You can think of it like a spreadsheet.
#Indexing in pandas means simply selecting particular rows and columns of data from a DataFrame.
#It is  also known as Subset Selection.
predictionsBasedOnKFolds = pd.DataFrame(data=[],index=y_train.index,columns=[0,1])
model = logReg

#kfold.split will generate indices to split data into training and test set (cv):
for train_index, cv_index in k_fold.split(np.zeros(len(X_train)),y_train.ravel()):

  #'iloc' can be used when the user doesn’t know the index label:
  #Here we are filtering the data based on indices. Data is divided as 902/225.
  X_train_fold, X_cv_fold = X_train.iloc[train_index,:], X_train.iloc[cv_index,:]
  y_train_fold, y_cv_fold = y_train.iloc[train_index], y_train.iloc[cv_index]

  #Fitting the model according to given data:
  #Note that model refers to logReg.
  model.fit(X_train_fold, y_train_fold)

  #Lets check how good is the fitting. Remember we decided to use log loss.
  # Log loss, aka logistic loss or cross-entropy loss.This is the loss function 
  # used in (multinomial) logistic regression and extensions of it such as neural networks.

  # We will fisrt look log loss in the training dataset. 
  loglossTraining = log_loss(y_train_fold,model.predict_proba(X_train_fold)[:,1])
  #Saving our analysis on the list:
  trainingScores.append(loglossTraining)

  #Lets see how good it is on CV dataset:
  predictionsBasedOnKFolds.loc[X_cv_fold.index,:] =model.predict_proba(X_cv_fold)
  loglossCV = log_loss(y_cv_fold,predictionsBasedOnKFolds.loc[X_cv_fold.index,1])
  #Saving our analysis on the list:
  cvScores.append(loglossCV)

  #printing the results:
  print('Training Log Loss: ', loglossTraining)
  print('CV Log Loss: ', loglossCV)

#Lets see the overall log loss for the entire training set (1127)
loglossLogisticRegression = log_loss(y_train,predictionsBasedOnKFolds.loc[:,1])
print('Logistic Regression Log Loss: ', loglossLogisticRegression)
# Out:
# Training Log Loss:  0.356738871444132
# CV Log Loss:  0.3908671819349346
# Training Log Loss:  0.3502213540664088
# CV Log Loss:  0.41923690251002477
# Training Log Loss:  0.36966720091349914
# CV Log Loss:  0.3416906749773056
# Training Log Loss:  0.3713443836483212
# CV Log Loss:  0.33109771302939867
# Training Log Loss:  0.3628451865203291
# CV Log Loss:  0.36564683099773154
# Logistic Regression Log Loss:  0.3697705832835482

# %% [markdown]
# Lets review the results.
#
# i) In general, what we expect is a training loss smaller than the CV loss. The reason is simple: ML algorithm learns from the training data so it should be better with the training set. CV is the data not included in the training set. In our case, we see that the training and cross-validation losses are similar for each run.
#
# ii) There is no over-fitting. If we had the overfitting, training log loss would be much lower than the cross-validation loss.

# %% [markdown]
# ## Evaluation Matrices

# %% [markdown]
# ### Confusion Matrix
#
# In binary classification, we can visualize the results via the confusion matrix:
#
# https://en.wikipedia.org/wiki/Confusion_matrix

# %%
y_preds = model.predict(X_train)

# %%
from sklearn.metrics import confusion_matrix, plot_confusion_matrix
confusion_matrix(y_train,y_preds)
# Out:
# array([[222, 100],
#        [ 35, 770]])

# %%
plot_confusion_matrix(model,X_train,y_train,cmap='Blues')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# For different color options, you may check:
#
# https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html

# %% [markdown]
# ### Precision-Recall Curve

# %%
preds = pd.concat([y_train,predictionsBasedOnKFolds.loc[:,1]], axis=1)
preds.columns = ['trueLabel','prediction']
predictionsBasedOnKFoldsLogisticRegression = preds.copy()
precision, recall, thresholds = precision_recall_curve(preds['trueLabel'],preds['prediction'])
average_precision = average_precision_score(preds['trueLabel'],preds['prediction'])

plt.step(recall, precision, color='k', alpha=0.7, where='post')
plt.fill_between(recall, precision, step='post', alpha=0.3, color='k')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('Precision-Recall curve: Average Precision = {0:0.2f}'.format(average_precision))
# Out:
# Text(0.5, 1.0, 'Precision-Recall curve: Average Precision = 0.94')

# %% [markdown]
# Here a high recall means that model has captured most of the true positives. As can be seen above, the average precision is good but not perfect.

# %% [markdown]
# ### Area under the Receiver Operating Characteristic (ROC) Curve
#
# This is another tool userful for binary classifiers. Below, the dotted line refers to a random classification (50% chance) so a good classifier should be away from the dotted line as much as possible; towards the top & left corner. In the ideal case, we will be at the top-left, implying that we have 0% false positive and 100% true positive rates.

# %%
fpr, tpr, thresholds = roc_curve(preds['trueLabel'],preds['prediction'])
areaUnderROC = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='r', lw=2, label='ROC curve')
plt.plot([0, 1], [0, 1], color='k', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic: Area under the curve = {0:0.2f}'.format(areaUnderROC))
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # Selecting a Different Approach I: Gradient Descent
#
# The data has already been prepared for a ML algorithm for logistic regression. Lets try couple of more classification algoritms and compare their performances.
#
# One useful model interface in scikit learn is the gradient descent classifier. It includes linear classifiers (SVM, logistic regression, etc.) with stochastic gradient descent (SGD) training. Note that the default learning model is the linear support vector machine (SVM). With this optimizer, we estimate the gradient of the loss for each sample at a time and the trainable model parameters are updated with decreasing learning rate (we will discuss it more in neural networks).
#
# An important note here is that with default settings, you should rescale the data to have zero mean and unit variance, as it relies on SVM. The other important feature of SGDClassifier is the partial_fit method and you can use it to implement the batch learning (instead of stochastic learning). If mini-batches are desired, we should further divide the data into mini-batches before feeding into the model.

# %%
# Hyperparameters:
#You need to check model descriptions for the hyperparameters. 
#https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
#-------------------------------------------------------------------------------------------------------------
#Loss definition:
# The loss function to be used. Defaults to ‘hinge’, which gives a linear SVM.
# The ‘log’ loss gives logistic regression, a probabilistic classifier.
# ‘modified_huber’ is another smooth loss that brings tolerance to outliers as well as probability estimates.
# ‘squared_hinge’ is like hinge but is quadratically penalized. 
# ‘perceptron’ is the linear loss used by the perceptron algorithm.
#-------------------------------------------------------------------------------------------------------------
loss = 'modified_huber' 
#-------------------------------------------------------------------------------------------------------------
# The regularization term to be used. Defaults to ‘l2’ which is the standard regularizer for linear SVM models:
penalty = 'elasticnet'
#The Elastic Net mixing parameter, with 0 <= l1_ratio <= 1. 
#l1_ratio=0 corresponds to L2 penalty, l1_ratio=1 to L1. 
l1_ratio = 0.15
#-------------------------------------------------------------------------------------------------------------
learning_rate = 'optimal'
# Constant that multiplies the regularization term. The higher the value, the stronger the regularization:
#-------------------------------------------------------------------------------------------------------------
# Regularization constant:
# used to compute the learning rate when set to learning_rate is set to ‘optimal’.
alpha = 0.0001 # Higher the value, higher the regularization.
#-------------------------------------------------------------------------------------------------------------
early_stopping = False # if true, terminate training when validation score is not improving. 
validation_fraction = 0.05 # portion of the training dataset utilized if early stopping is True. 
#-------------------------------------------------------------------------------------------------------------
random_state = 2021
#-------------------------------------------------------------------------------------------------------------

SGD = SGDClassifier(loss=loss, penalty=penalty, alpha=alpha,l1_ratio=l1_ratio, early_stopping=early_stopping, learning_rate=learning_rate, validation_fraction= validation_fraction, random_state=random_state)

# %%
# Model Training:
#-----------------------------------------------------------------------------
#Lists for storing scores
trainingScores = []
cvScores = []

#DataFrame is a 2-dimensional labeled data structure. You can think of it like a spreadsheet.
#Indexing in pandas means simply selecting particular rows and columns of data from a DataFrame.
#It is  also known as Subset Selection.
predictionsBasedOnKFolds = pd.DataFrame(data=[],index=y_train.index,columns=[0,1])

#_______________#
#___Modified:___#
model = SGD

#kfold.split will generate indices to split data into training and test set (cv):
for train_index, cv_index in k_fold.split(np.zeros(len(X_train)),y_train.ravel()):

  #'iloc' can be used when the user doesn’t know the index label:
  #Here we are filtering the data based on indices. Data is divided as 902/225.
  X_train_fold, X_cv_fold = X_train.iloc[train_index,:], X_train.iloc[cv_index,:]
  y_train_fold, y_cv_fold = y_train.iloc[train_index], y_train.iloc[cv_index]

  #Fitting the model according to given data:
  #Note that model refers to SGD.
  model.fit(X_train_fold, y_train_fold)

  #Lets check how good is the fitting. Remember we decided to use log loss.
  # Log loss, aka logistic loss or cross-entropy loss.This is the loss function 
  # used in (multinomial) logistic regression and extensions of it such as neural networks.

  # We will fisrt look log loss in the training dataset. 
  loglossTraining = log_loss(y_train_fold,model.predict_proba(X_train_fold)[:,1])
  #Saving our analysis on the list:
  trainingScores.append(loglossTraining)

  #Lets see how good it is on CV dataset:
  predictionsBasedOnKFolds.loc[X_cv_fold.index,:] =model.predict_proba(X_cv_fold)
  loglossCV = log_loss(y_cv_fold,predictionsBasedOnKFolds.loc[X_cv_fold.index,1])
  #Saving our analysis on the list:
  cvScores.append(loglossCV)

  #printing the results:
  print('Training Log Loss: ', loglossTraining)
  print('CV Log Loss: ', loglossCV)

#Lets see the overall log loss for the entire training set (1127)
#_______________#
#___Modified:___#
loglossSGD = log_loss(y_train,predictionsBasedOnKFolds.loc[:,1])
print('-----------------------------------')
print('SGD Log Loss: ', loglossSGD)
# Out:
# Training Log Loss:  3.586671974219637
# CV Log Loss:  4.100610579512294
# Training Log Loss:  5.277033917268186
# CV Log Loss:  4.439710331344868
# Training Log Loss:  2.6658351181973594
# CV Log Loss:  2.5979833037912936
# Training Log Loss:  2.9737704271204604
# CV Log Loss:  1.9032024383230322
# Training Log Loss:  7.6863927611524065
# CV Log Loss:  5.510248719919679
# -----------------------------------
# SGD Log Loss:  3.711344525121002

# %% [markdown]
# ## Evaluation Matrices

# %% [markdown]
# ### Confusion Matrix
#
# In binary classification, we can visualize the results via the confusion matrix:
#
# https://en.wikipedia.org/wiki/Confusion_matrix

# %%
y_preds = model.predict(X_train)
confusion_matrix(y_train,y_preds)
# Out:
# array([[280,  42],
#        [314, 491]])

# %%
plot_confusion_matrix(model,X_train,y_train,cmap='Blues')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ### PR Curve

# %%
preds = pd.concat([y_train,predictionsBasedOnKFolds.loc[:,1]], axis=1)
preds.columns = ['trueLabel','prediction']
predictionsBasedOnKFoldsLogisticRegression = preds.copy()
precision, recall, thresholds = precision_recall_curve(preds['trueLabel'],preds['prediction'])
average_precision = average_precision_score(preds['trueLabel'],preds['prediction'])

plt.step(recall, precision, color='k', alpha=0.7, where='post')
plt.fill_between(recall, precision, step='post', alpha=0.3, color='k')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('Precision-Recall curve: Average Precision = {0:0.2f}'.format(average_precision))
# Out:
# Text(0.5, 1.0, 'Precision-Recall curve: Average Precision = 0.88')

# %% [markdown]
# ### Area under the Receiver Operating Characteristic (ROC) Curve
#
# This is another tool userful for binary classifiers. Below, the dotted line refers to a random classification (50% chance) so a good classifier should be away from the dotted line as much as possible; towards the top & left corner. In the ideal case, we will be at the top-left, implying that we have 0% false positive and 100% true positive rates.

# %%
fpr, tpr, thresholds = roc_curve(preds['trueLabel'],preds['prediction'])
areaUnderROC = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='r', lw=2, label='ROC curve')
plt.plot([0, 1], [0, 1], color='k', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic: Area under the curve = {0:0.2f}'.format(areaUnderROC))
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # Selecting a Different Approach II: Random Forests
# Lets try another popular method: Random Forests.

# %%
# Hyperparameters:
#You need to check model descriptions for the hyperparameters. 
#https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html?highlight=random%20forest#sklearn.ensemble.RandomForestClassifier
#-----------------------------------------------------------------
# Number of trees in the forest:
n_estimators = 10
# Number of features to consider when looking for the best split:
max_features = 'auto'
# Maximum depth of the tree:
max_depth = None
# Minimum number of samples required to split an internal node:
min_samples_split = 2
# Minimum number of samples required to be at a leaf node:
min_samples_leaf = 1
# Grow trees with max_leaf_nodes in best-first fashion. Best nodes are defined as relative reduction in impurity. 
max_leaf_nodes = None
# Whether bootstrap samples are used when building trees. If False, the whole dataset is used to build each tree:
bootstrap = False
# Whether to use out-of-bag samples to estimate the generalization score. Only available if bootstrap=True.
oob_score = False
# Number of jobs to run in parallel. (-1) means use all.
n_jobs = -1
# Random state
random_state = 2021
#-----------------------------------------------------------------
# Creating the classifier:
RFC = RandomForestClassifier(n_estimators=n_estimators, max_features=max_features, max_depth=max_depth, min_samples_split=min_samples_split, min_samples_leaf=min_samples_leaf, \
                              max_leaf_nodes=max_leaf_nodes, bootstrap=bootstrap,oob_score=oob_score, n_jobs=n_jobs, random_state=random_state)

# %%
# Model Training:
#-----------------------------------------------------------------------------
#Lists for storing scores
trainingScores = []
cvScores = []

#DataFrame is a 2-dimensional labeled data structure. You can think of it like a spreadsheet.
#Indexing in pandas means simply selecting particular rows and columns of data from a DataFrame.
#It is  also known as Subset Selection.
predictionsBasedOnKFolds = pd.DataFrame(data=[],index=y_train.index,columns=[0,1])

#_______________#
#___Modified:___#
model = RFC

#kfold.split will generate indices to split data into training and test set (cv):
for train_index, cv_index in k_fold.split(np.zeros(len(X_train)),y_train.ravel()):

  #'iloc' can be used when the user doesn’t know the index label:
  #Here we are filtering the data based on indices. Data is divided as 902/225.
  X_train_fold, X_cv_fold = X_train.iloc[train_index,:], X_train.iloc[cv_index,:]
  y_train_fold, y_cv_fold = y_train.iloc[train_index], y_train.iloc[cv_index]

  #Fitting the model according to given data:
  #Note that model refers to FRC.
  model.fit(X_train_fold, y_train_fold)

  #Lets check how good is the fitting. Remember we decided to use log loss.
  # Log loss, aka logistic loss or cross-entropy loss.This is the loss function 
  # used in (multinomial) logistic regression and extensions of it such as neural networks.

  # We will fisrt look log loss in the training dataset. 
  loglossTraining = log_loss(y_train_fold,model.predict_proba(X_train_fold)[:,1])
  #Saving our analysis on the list:
  trainingScores.append(loglossTraining)

  #Lets see how good it is on CV dataset:
  predictionsBasedOnKFolds.loc[X_cv_fold.index,:] =model.predict_proba(X_cv_fold)
  loglossCV = log_loss(y_cv_fold,predictionsBasedOnKFolds.loc[X_cv_fold.index,1])
  #Saving our analysis on the list:
  cvScores.append(loglossCV)

  #printing the results:
  print('Training Log Loss: ', loglossTraining)
  print('CV Log Loss: ', loglossCV)

#Lets see the overall log loss for the entire training set (1127)
#_______________#
#___Modified:___#
loglossRFC = log_loss(y_train,predictionsBasedOnKFolds.loc[:,1])
print('-----------------------------------')
print('SGD Log Loss: ', loglossRFC)
# Out:
# Training Log Loss:  9.992007221626413e-16
# CV Log Loss:  0.7178970540366597
# Training Log Loss:  9.992007221626413e-16
# CV Log Loss:  0.7451343982249555
# Training Log Loss:  9.992007221626413e-16
# CV Log Loss:  0.300889727363023
# Training Log Loss:  9.992007221626413e-16
# CV Log Loss:  0.28273205413303126
# Training Log Loss:  9.992007221626413e-16
# CV Log Loss:  1.0590139288805958
# -----------------------------------
# SGD Log Loss:  0.6213293194728228

# %% [markdown]
# ### RF Special Property: Feature Importance
# Scikit-Learn measures a feature’s importance by looking at how much the tree nodes that use that feature reduce impurity on average (across all trees in the forest).
#
# Scikit-Learn computes this score automatically for each feature after training, then it scales the results so that the sum of all importances is equal to 1. You can access the result using the `feature_importances_` variable.

# %%
pred_comp = model.fit(X_train, y_train)
for name, score in zip(new_names, pred_comp.feature_importances_):
    print(name, score)
# Out:
# frequency 0.5176373223283247
# angle_attack 0.08381403749858175
# chord_length 0.11638513300666546
# Free-stream_velocity 0.050050474019794046
# displacement_thickness 0.23211303314663412

# %% [markdown]
# ## Evaluation Matrices

# %% [markdown]
# ### Confusion Matrix

# %%
y_preds = model.predict(X_train)
confusion_matrix(y_train,y_preds)
# Out:
# array([[322,   0],
#        [  0, 805]])

# %%
plot_confusion_matrix(model,X_train,y_train,cmap='Blues')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ### PR Curve

# %%
preds = pd.concat([y_train,predictionsBasedOnKFolds.loc[:,1]], axis=1)
preds.columns = ['trueLabel','prediction']
predictionsBasedOnKFoldsLogisticRegression = preds.copy()
precision, recall, thresholds = precision_recall_curve(preds['trueLabel'],preds['prediction'])
average_precision = average_precision_score(preds['trueLabel'],preds['prediction'])

plt.step(recall, precision, color='k', alpha=0.7, where='post')
plt.fill_between(recall, precision, step='post', alpha=0.3, color='k')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('Precision-Recall curve: Average Precision = {0:0.2f}'.format(average_precision))
# Out:
# Text(0.5, 1.0, 'Precision-Recall curve: Average Precision = 0.97')

# %% [markdown]
# ### ROC Curve

# %%
fpr, tpr, thresholds = roc_curve(preds['trueLabel'],preds['prediction'])
areaUnderROC = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='r', lw=2, label='ROC curve')
plt.plot([0, 1], [0, 1], color='k', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic: Area under the curve = {0:0.2f}'.format(areaUnderROC))
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # Selecting a Different Approach III: Boosting

# %% [markdown]
# Introduced by Microsoft in 2017, LightGBM is designed for modeling extremely large data sets of high dimensionality, often being many times faster than XGBoost.
#
# For its own documentation:
# https://lightgbm.readthedocs.io/en/latest/

# %%
# Hyperparameters:
#You need to check model descriptions for the hyperparameters. 
# https://lightgbm.readthedocs.io/en/latest/Parameters.html#parameters-format

params_LGB = {
'task': 'train',
'application':'binary',
'num_class':1,
'boosting': 'gbdt', # traditional Gradient Boosting Decision Tree
'objective': 'binary',
'metric': 'binary_logloss', #our initial selection
'metric_freq':1, # default = 1, type = int, aliases: output_freq, constraints: metric_freq > 0
'training_metric':False, #set this to true to output metric result over training dataset
'max_depth':4, #limit the max depth for tree model. This is used to deal with over-fitting when #data is small. Tree still grows leaf-wise
'num_leaves': 10, #default = 31, type = int, constraints: 1 < num_leaves <= 131072
'learning_rate': 0.01, #default = 0.1  constraints: learning_rate > 0.0
'feature_fraction': 1.0,  # default = 1.0. #LightGBM will randomly select part of features on each iteration (tree) if feature_fraction smaller than 1.0. For example, if you set it to 0.8, LightGBM will select 80% of features before training each tree
#can be used to speed up training or  to deal with over-fitting.
'bagging_fraction': 1.0, # default = 1.0. this will randomly select part of data without resampling. can be used to deal with over-fitting. 0.0 < bagging_fraction <= 1.0
'bagging_freq': 0, # 0 means disable bagging; k means perform bagging at every k iteration
'bagging_seed': 2021, #random seed for bagging
'verbose': -1, #default = 1 controls the level of LightGBM’s verbosity. = 0: Error (Warning), = 1: Info, > 1: Debug  
'num_threads':0 # default = 0, 
# for the best speed, set this to the number of real CPU cores, not the number of threads
# do not set it too large if your dataset is small (for instance, do not use 64 threads for a dataset with 10,000 rows)
}

# %%
# Model Training:
#-----------------------------------------------------------------------------
#Lists for storing scores
trainingScores = []
cvScores = []

#DataFrame is a 2-dimensional labeled data structure. You can think of it like a spreadsheet.
#Indexing in pandas means simply selecting particular rows and columns of data from a DataFrame.
#It is  also known as Subset Selection.
predictionsBasedOnKFolds = pd.DataFrame(data=[],index=y_train.index,columns=['prediction'])

#_______________#
#___Modified:___#
#model not defined here!

#kfold.split will generate indices to split data into training and test set (cv):
for train_index, cv_index in k_fold.split(np.zeros(len(X_train)),y_train.ravel()):

  #'iloc' can be used when the user doesn’t know the index label:
  #Here we are filtering the data based on indices. Data is divided as 902/225.
  X_train_fold, X_cv_fold = X_train.iloc[train_index,:], X_train.iloc[cv_index,:]
  y_train_fold, y_cv_fold = y_train.iloc[train_index], y_train.iloc[cv_index]

  #Fitting the model according to given data:
  #_______________#
  #___Modified:___#
  train_LGB = LGBMClassifier.Dataset(X_train_fold, y_train_fold)
  evaluate_LGB = LGBMClassifier.Dataset(X_cv_fold, y_cv_fold, reference = train_LGB)
  #Calling the model for training:
  GBM = LGBMClassifier.train(params_LGB,train_LGB, num_boost_round = 2500, valid_sets = evaluate_LGB, early_stopping_rounds = 150)

  #Lets check how good is the fitting. Remember we decided to use log loss.
  # Log loss, aka logistic loss or cross-entropy loss.This is the loss function 
  # used in (multinomial) logistic regression and extensions of it such as neural networks.
  # We will fisrt look log loss in the training dataset. 
  
  #_______________#
  #___Modified:___#
  loglossTraining = log_loss(y_train_fold, GBM.predict(X_train_fold, num_iteration=GBM.best_iteration))
  
  #Saving our analysis on the list:
  trainingScores.append(loglossTraining)

  #_______________#
  #___Modified:___#
  #Lets see how good it is on CV dataset:
  predictionsBasedOnKFolds.loc[X_cv_fold.index,'prediction'] =GBM.predict(X_cv_fold, num_iteration=GBM.best_iteration)
  
  loglossCV = log_loss(y_cv_fold,predictionsBasedOnKFolds.loc[X_cv_fold.index,'prediction'])
  #Saving our analysis on the list:
  cvScores.append(loglossCV)

  #printing the results:
  print('Training Log Loss: ', loglossTraining)
  print('CV Log Loss: ', loglossCV)

#Lets see the overall log loss for the entire training set (1127)
#_______________#
#___Modified:___#
loglossLGBMC = log_loss(y_train,predictionsBasedOnKFolds.loc[:,'prediction'])
print('-----------------------------------')
print('SGD Log Loss: ', loglossLGBMC)
# Out:
# Streaming output truncated to the last 5000 lines.
# [1130]	valid_0's binary_logloss: 0.17883
# [1131]	valid_0's binary_logloss: 0.178744
# [1132]	valid_0's binary_logloss: 0.178734
# [1133]	valid_0's binary_logloss: 0.178693
# [1134]	valid_0's binary_logloss: 0.178601
# [1135]	valid_0's binary_logloss: 0.17866
# [1136]	valid_0's binary_logloss: 0.178613
# [1137]	valid_0's binary_logloss: 0.178516
# [1138]	valid_0's binary_logloss: 0.178499
# [1139]	valid_0's binary_logloss: 0.178416
# [1140]	valid_0's binary_logloss: 0.17841
# [1141]	valid_0's binary_logloss: 0.178321
# [1142]	valid_0's binary_logloss: 0.178294
# [1143]	valid_0's binary_logloss: 0.178242
# [1144]	valid_0's binary_logloss: 0.178202
# [1145]	valid_0's binary_logloss: 0.178176
# [1146]	valid_0's binary_logloss: 0.178235
# [1147]	valid_0's binary_logloss: 0.178191
# [1148]	valid_0's binary_logloss: 0.178141
# [1149]	valid_0's binary_logloss: 0.178083
# [1150]	valid_0's binary_logloss: 0.178034
# [1151]	valid_0's binary_logloss: 0.178057
# [1152]	valid_0's binary_logloss: 0.177969
# [1153]	valid_0's binary_logloss: 0.177944
# [1154]	valid_0's binary_logloss: 0.177893
# [1155]	valid_0's binary_logloss: 0.177856
# [1156]	valid_0's binary_logloss: 0.177916
# [1157]	valid_0's binary_logloss: 0.177871
# [1158]	valid_0's binary_logloss: 0.177784
# [1159]	valid_0's binary_logloss: 0.177735
# [1160]	valid_0's binary_logloss: 0.177648
# [1161]	valid_0's binary_logloss: 0.177556
# [1162]	valid_0's binary_logloss: 0.177557
# [1163]	valid_0's binary_logloss: 0.177548
# [1164]	valid_0's binary_logloss: 0.1775
# [1165]	valid_0's binary_logloss: 0.177458
# [1166]	valid_0's binary_logloss: 0.177372
# [1167]	valid_0's binary_logloss: 0.177348
# [1168]	valid_0's binary_logloss: 0.177377
# [1169]	valid_0's binary_logloss: 0.177336
# [1170]	valid_0's binary_logloss: 0.177255
# [1171]	valid_0's binary_logloss: 0.17725
# [1172]	valid_0's binary_logloss: 0.177138
# [1173]	valid_0's binary_logloss: 0.177054
# [1174]	valid_0's binary_logloss: 0.176969
# [1175]	valid_0's binary_logloss: 0.176922
# [1176]	valid_0's binary_logloss: 0.176894
# [1177]	valid_0's binary_logloss: 0.176814
# [1178]	valid_0's binary_logloss: 0.176798
# [1179]	valid_0's binary_logloss: 0.176777
# [1180]	valid_0's binary_logloss: 0.176731
# [1181]	valid_0's binary_logloss: 0.176719
# [1182]	valid_0's binary_logloss: 0.176684
# [1183]	valid_0's binary_logloss: 0.1766
# [1184]	valid_0's binary_logloss: 0.17649
# [1185]	valid_0's binary_logloss: 0.176492
# [1186]	valid_0's binary_logloss: 0.176452
# [1187]	valid_0's binary_logloss: 0.176407
# [1188]	valid_0's binary_logloss: 0.176387
# [1189]	valid_0's binary_logloss: 0.176279
# [1190]	valid_0's binary_logloss: 0.176244
# [1191]	valid_0's binary_logloss: 0.176226
# [1192]	valid_0's binary_logloss: 0.176146
# [1193]	valid_0's binary_logloss: 0.176042
# [1194]	valid_0's binary_logloss: 0.176077
# [1195]	valid_0's binary_logloss: 0.175999
# [1196]	valid_0's binary_logloss: 0.175955
# [1197]	valid_0's binary_logloss: 0.175991
# [1198]	valid_0's binary_logloss: 0.175946
# [1199]	valid_0's binary_logloss: 0.175873
# [1200]	valid_0's binary_logloss: 0.175892
# [1201]	valid_0's binary_logloss: 0.175892
# [1202]	valid_0's binary_logloss: 0.175852
# [1203]	valid_0's binary_logloss: 0.175796
# [1204]	valid_0's binary_logloss: 0.175694
# [1205]	valid_0's binary_logloss: 0.175708
# [1206]	valid_0's binary_logloss: 0.175673
# [1207]	valid_0's binary_logloss: 0.175573
# [1208]	valid_0's binary_logloss: 0.175595
# [1209]	valid_0's binary_logloss: 0.17556
# [1210]	valid_0's binary_logloss: 0.175505
# [1211]	valid_0's binary_logloss: 0.175517
# [1212]	valid_0's binary_logloss: 0.175517
# [1213]	valid_0's binary_logloss: 0.175457
# [1214]	valid_0's binary_logloss: 0.175447
# [1215]	valid_0's binary_logloss: 0.17546
# [1216]	valid_0's binary_logloss: 0.175478
# [1217]	valid_0's binary_logloss: 0.175442
# [1218]	valid_0's binary_logloss: 0.175434
# [1219]	valid_0's binary_logloss: 0.17546
# [1220]	valid_0's binary_logloss: 0.175407
# [1221]	valid_0's binary_logloss: 0.175375
# [1222]	valid_0's binary_logloss: 0.175361
# [1223]	valid_0's binary_logloss: 0.175378
# [1224]	valid_0's binary_logloss: 0.175299
# [1225]	valid_0's binary_logloss: 0.175312
# [1226]	valid_0's binary_logloss: 0.17527
# [1227]	valid_0's binary_logloss: 0.175195
# [1228]	valid_0's binary_logloss: 0.175209
# [1229]	valid_0's binary_logloss: 0.175155
# [1230]	valid_0's binary_logloss: 0.175079
# [1231]	valid_0's binary_logloss: 0.175037
# [1232]	valid_0's binary_logloss: 0.174987
# [1233]	valid_0's binary_logloss: 0.17489
# [1234]	valid_0's binary_logloss: 0.174929
# [1235]	valid_0's binary_logloss: 0.175004
# [1236]	valid_0's binary_logloss: 0.175001
# [1237]	valid_0's binary_logloss: 0.174927
# [1238]	valid_0's binary_logloss: 0.174888
# [1239]	valid_0's binary_logloss: 0.174894
# [1240]	valid_0's binary_logloss: 0.174856
# [1241]	valid_0's binary_logloss: 0.174798
# [1242]	valid_0's binary_logloss: 0.17475
# [1243]	valid_0's binary_logloss: 0.174789
# [1244]	valid_0's binary_logloss: 0.174741
# [1245]	valid_0's binary_logloss: 0.174712
# [1246]	valid_0's binary_logloss: 0.17472
# [1247]	valid_0's binary_logloss: 0.174673
# [1248]	valid_0's binary_logloss: 0.1747
# [1249]	valid_0's binary_logloss: 0.174665
# [1250]	valid_0's binary_logloss: 0.174647
# [1251]	valid_0's binary_logloss: 0.174665
# [1252]	valid_0's binary_logloss: 0.174594
# [1253]	valid_0's binary_logloss: 0.174557
# [1254]	valid_0's binary_logloss: 0.174631
# [1255]	valid_0's binary_logloss: 0.17459
# [1256]	valid_0's binary_logloss: 0.174519
# [1257]	valid_0's binary_logloss: 0.174594
# [1258]	valid_0's binary_logloss: 0.174553
# [1259]	valid_0's binary_logloss: 0.174581
# [1260]	valid_0's binary_logloss: 0.174514
# [1261]	valid_0's binary_logloss: 0.17453
# [1262]	valid_0's binary_logloss: 0.174452
# [1263]	valid_0's binary_logloss: 0.174373
# [1264]	valid_0's binary_logloss: 0.1743
# [1265]	valid_0's binary_logloss: 0.17429
# [1266]	valid_0's binary_logloss: 0.174283
# [1267]	valid_0's binary_logloss: 0.174245
# [1268]	valid_0's binary_logloss: 0.174204
# [1269]	valid_0's binary_logloss: 0.174139
# [1270]	valid_0's binary_logloss: 0.174043
# [1271]	valid_0's binary_logloss: 0.173963
# [1272]	valid_0's binary_logloss: 0.173919
# [1273]	valid_0's binary_logloss: 0.173935
# [1274]	valid_0's binary_logloss: 0.173902
# [1275]	valid_0's binary_logloss: 0.173835
# [1276]	valid_0's binary_logloss: 0.173742
# [1277]	valid_0's binary_logloss: 0.173749
# [1278]	valid_0's binary_logloss: 0.173778
# [1279]	valid_0's binary_logloss: 0.173713
# [1280]	valid_0's binary_logloss: 0.173661
# [1281]	valid_0's binary_logloss: 0.173695
# [1282]	valid_0's binary_logloss: 0.173697
# [1283]	valid_0's binary_logloss: 0.173662
# [1284]	valid_0's binary_logloss: 0.173606
# [1285]	valid_0's binary_logloss: 0.173615
# [1286]	valid_0's binary_logloss: 0.173577
# [1287]	valid_0's binary_logloss: 0.173572
# [1288]	valid_0's binary_logloss: 0.173613
# [1289]	valid_0's binary_logloss: 0.17355
# [1290]	valid_0's binary_logloss: 0.173472
# [1291]	valid_0's binary_logloss: 0.17338
# [1292]	valid_0's binary_logloss: 0.173391
# [1293]	valid_0's binary_logloss: 0.173334
# [1294]	valid_0's binary_logloss: 0.173301
# [1295]	valid_0's binary_logloss: 0.17321
# [1296]	valid_0's binary_logloss: 0.173143
# [1297]	valid_0's binary_logloss: 0.17316
# [1298]	valid_0's binary_logloss: 0.173121
# [1299]	valid_0's binary_logloss: 0.173056
# [1300]	valid_0's binary_logloss: 0.172995
# [1301]	valid_0's binary_logloss: 0.172906
# [1302]	valid_0's binary_logloss: 0.172818
# [1303]	valid_0's binary_logloss: 0.172853
# [1304]	valid_0's binary_logloss: 0.172865
# [1305]	valid_0's binary_logloss: 0.172869
# [1306]	valid_0's binary_logloss: 0.172843
# [1307]	valid_0's binary_logloss: 0.172789
# [1308]	valid_0's binary_logloss: 0.172806
# [1309]	valid_0's binary_logloss: 0.172759
# [1310]	valid_0's binary_logloss: 0.172707
# [1311]	valid_0's binary_logloss: 0.172749
# [1312]	valid_0's binary_logloss: 0.17269
# [1313]	valid_0's binary_logloss: 0.172657
# [1314]	valid_0's binary_logloss: 0.172624
# [1315]	valid_0's binary_logloss: 0.172634
# [1316]	valid_0's binary_logloss: 0.172557
# [1317]	valid_0's binary_logloss: 0.172494
# [1318]	valid_0's binary_logloss: 0.17247
# [1319]	valid_0's binary_logloss: 0.172492
# [1320]	valid_0's binary_logloss: 0.17246
# [1321]	valid_0's binary_logloss: 0.172394
# [1322]	valid_0's binary_logloss: 0.172235
# [1323]	valid_0's binary_logloss: 0.172309
# [1324]	valid_0's binary_logloss: 0.172307
# [1325]	valid_0's binary_logloss: 0.172318
# [1326]	valid_0's binary_logloss: 0.172261
# [1327]	valid_0's binary_logloss: 0.172106
# [1328]	valid_0's binary_logloss: 0.172069
# [1329]	valid_0's binary_logloss: 0.172015
# [1330]	valid_0's binary_logloss: 0.171983
# [1331]	valid_0's binary_logloss: 0.171934
# [1332]	valid_0's binary_logloss: 0.171914
# [1333]	valid_0's binary_logloss: 0.171856
# [1334]	valid_0's binary_logloss: 0.171803
# [1335]	valid_0's binary_logloss: 0.171799
# [1336]	valid_0's binary_logloss: 0.171761
# [1337]	valid_0's binary_logloss: 0.17171
# [1338]	valid_0's binary_logloss: 0.171662
# [1339]	valid_0's binary_logloss: 0.171635
# [1340]	valid_0's binary_logloss: 0.171671
# [1341]	valid_0's binary_logloss: 0.171639
# [1342]	valid_0's binary_logloss: 0.171585
# [1343]	valid_0's binary_logloss: 0.171582
# [1344]	valid_0's binary_logloss: 0.171579
# [1345]	valid_0's binary_logloss: 0.171582
# [1346]	valid_0's binary_logloss: 0.171575
# [1347]	valid_0's binary_logloss: 0.171611
# [1348]	valid_0's binary_logloss: 0.171609
# [1349]	valid_0's binary_logloss: 0.171634
# [1350]	valid_0's binary_logloss: 0.171596
# [1351]	valid_0's binary_logloss: 0.171559
# [1352]	valid_0's binary_logloss: 0.171596
# [1353]	valid_0's binary_logloss: 0.171671
# [1354]	valid_0's binary_logloss: 0.171665
# [1355]	valid_0's binary_logloss: 0.171626
# [1356]	valid_0's binary_logloss: 0.171664
# [1357]	valid_0's binary_logloss: 0.171627
# [1358]	valid_0's binary_logloss: 0.171625
# [1359]	valid_0's binary_logloss: 0.171664
# [1360]	valid_0's binary_logloss: 0.171598
# [1361]	valid_0's binary_logloss: 0.171545
# [1362]	valid_0's binary_logloss: 0.171394
# [1363]	valid_0's binary_logloss: 0.171392
# [1364]	valid_0's binary_logloss: 0.17131
# [1365]	valid_0's binary_logloss: 0.171385
# [1366]	valid_0's binary_logloss: 0.171328
# [1367]	valid_0's binary_logloss: 0.171328
# [1368]	valid_0's binary_logloss: 0.171294
# [1369]	valid_0's binary_logloss: 0.171258
# [1370]	valid_0's binary_logloss: 0.171252
# [1371]	valid_0's binary_logloss: 0.171187
# [1372]	valid_0's binary_logloss: 0.171148
# [1373]	valid_0's binary_logloss: 0.171091
# [1374]	valid_0's binary_logloss: 0.171069
# [1375]	valid_0's binary_logloss: 0.171042
# [1376]	valid_0's binary_logloss: 0.171005
# [1377]	valid_0's binary_logloss: 0.170978
# [1378]	valid_0's binary_logloss: 0.170981
# [1379]	valid_0's binary_logloss: 0.170981
# [1380]	valid_0's binary_logloss: 0.17102
# [1381]	valid_0's binary_logloss: 0.171005
# [1382]	valid_0's binary_logloss: 0.171033
# [1383]	valid_0's binary_logloss: 0.171003
# [1384]	valid_0's binary_logloss: 0.171078
# [1385]	valid_0's binary_logloss: 0.171077
# [1386]	valid_0's binary_logloss: 0.171033
# [1387]	valid_0's binary_logloss: 0.170981
# [1388]	valid_0's binary_logloss: 0.17101
# [1389]	valid_0's binary_logloss: 0.170972
# [1390]	valid_0's binary_logloss: 0.170917
# [1391]	valid_0's binary_logloss: 0.170791
# [1392]	valid_0's binary_logloss: 0.170785
# [1393]	valid_0's binary_logloss: 0.170741
# [1394]	valid_0's binary_logloss: 0.170685
# [1395]	valid_0's binary_logloss: 0.170649
# [1396]	valid_0's binary_logloss: 0.170691
# [1397]	valid_0's binary_logloss: 0.170654
# [1398]	valid_0's binary_logloss: 0.170595
# [1399]	valid_0's binary_logloss: 0.170604
# [1400]	valid_0's binary_logloss: 0.170599
# [1401]	valid_0's binary_logloss: 0.170642
# [1402]	valid_0's binary_logloss: 0.170642
# [1403]	valid_0's binary_logloss: 0.170667
# [1404]	valid_0's binary_logloss: 0.170614
# [1405]	valid_0's binary_logloss: 0.170588
# [1406]	valid_0's binary_logloss: 0.170554
# [1407]	valid_0's binary_logloss: 0.170507
# [1408]	valid_0's binary_logloss: 0.170508
# [1409]	valid_0's binary_logloss: 0.170525
# [1410]	valid_0's binary_logloss: 0.170483
# [1411]	valid_0's binary_logloss: 0.170527
# [1412]	valid_0's binary_logloss: 0.170477
# [1413]	valid_0's binary_logloss: 0.170424
# [1414]	valid_0's binary_logloss: 0.1703
# [1415]	valid_0's binary_logloss: 0.170297
# [1416]	valid_0's binary_logloss: 0.170245
# [1417]	valid_0's binary_logloss: 0.170223
# [1418]	valid_0's binary_logloss: 0.170268
# [1419]	valid_0's binary_logloss: 0.170223
# [1420]	valid_0's binary_logloss: 0.170174
# [1421]	valid_0's binary_logloss: 0.170052
# [1422]	valid_0's binary_logloss: 0.169986
# [1423]	valid_0's binary_logloss: 0.170001
# [1424]	valid_0's binary_logloss: 0.169998
# [1425]	valid_0's binary_logloss: 0.170043
# [1426]	valid_0's binary_logloss: 0.170025
# [1427]	valid_0's binary_logloss: 0.1701
# [1428]	valid_0's binary_logloss: 0.170098
# [1429]	valid_0's binary_logloss: 0.170046
# [1430]	valid_0's binary_logloss: 0.170105
# [1431]	valid_0's binary_logloss: 0.170071
# [1432]	valid_0's binary_logloss: 0.17005
# [1433]	valid_0's binary_logloss: 0.170009
# [1434]	valid_0's binary_logloss: 0.16996
# [1435]	valid_0's binary_logloss: 0.169938
# [1436]	valid_0's binary_logloss: 0.169893
# [1437]	valid_0's binary_logloss: 0.169843
# [1438]	valid_0's binary_logloss: 0.16981
# [1439]	valid_0's binary_logloss: 0.169814
# [1440]	valid_0's binary_logloss: 0.169796
# [1441]	valid_0's binary_logloss: 0.169823
# [1442]	valid_0's binary_logloss: 0.169774
# [1443]	valid_0's binary_logloss: 0.169735
# [1444]	valid_0's binary_logloss: 0.169796
# [1445]	valid_0's binary_logloss: 0.169763
# [1446]	valid_0's binary_logloss: 0.169743
# [1447]	valid_0's binary_logloss: 0.169696
# [1448]	valid_0's binary_logloss: 0.169678
# [1449]	valid_0's binary_logloss: 0.169659
# [1450]	valid_0's binary_logloss: 0.169611
# [1451]	valid_0's binary_logloss: 0.169579
# [1452]	valid_0's binary_logloss: 0.169563
# [1453]	valid_0's binary_logloss: 0.169591
# [1454]	valid_0's binary_logloss: 0.169553
# [1455]	valid_0's binary_logloss: 0.169535
# [1456]	valid_0's binary_logloss: 0.169488
# [1457]	valid_0's binary_logloss: 0.169456
# [1458]	valid_0's binary_logloss: 0.169378
# [1459]	valid_0's binary_logloss: 0.169323
# [1460]	valid_0's binary_logloss: 0.169292
# [1461]	valid_0's binary_logloss: 0.169246
# [1462]	valid_0's binary_logloss: 0.169228
# [1463]	valid_0's binary_logloss: 0.169183
# [1464]	valid_0's binary_logloss: 0.169148
# [1465]	valid_0's binary_logloss: 0.169153
# [1466]	valid_0's binary_logloss: 0.169077
# [1467]	valid_0's binary_logloss: 0.169031
# [1468]	valid_0's binary_logloss: 0.16893
# [1469]	valid_0's binary_logloss: 0.16893
# [1470]	valid_0's binary_logloss: 0.168855
# [1471]	valid_0's binary_logloss: 0.168831
# [1472]	valid_0's binary_logloss: 0.1688
# [1473]	valid_0's binary_logloss: 0.168769
# [1474]	valid_0's binary_logloss: 0.168753
# [1475]	valid_0's binary_logloss: 0.168736
# [1476]	valid_0's binary_logloss: 0.168713
# [1477]	valid_0's binary_logloss: 0.168639
# [1478]	valid_0's binary_logloss: 0.168607
# [1479]	valid_0's binary_logloss: 0.168591
# [1480]	valid_0's binary_logloss: 0.168593
# [1481]	valid_0's binary_logloss: 0.168647
# [1482]	valid_0's binary_logloss: 0.168596
# [1483]	valid_0's binary_logloss: 0.168566
# [1484]	valid_0's binary_logloss: 0.168544
# [1485]	valid_0's binary_logloss: 0.168484
# [1486]	valid_0's binary_logloss: 0.168468
# [1487]	valid_0's binary_logloss: 0.168418
# [1488]	valid_0's binary_logloss: 0.168404
# [1489]	valid_0's binary_logloss: 0.168379
# [1490]	valid_0's binary_logloss: 0.168308
# [1491]	valid_0's binary_logloss: 0.168278
# [1492]	valid_0's binary_logloss: 0.168248
# [1493]	valid_0's binary_logloss: 0.168233
# [1494]	valid_0's binary_logloss: 0.16817
# [1495]	valid_0's binary_logloss: 0.168149
# [1496]	valid_0's binary_logloss: 0.16813
# [1497]	valid_0's binary_logloss: 0.168132
# [1498]	valid_0's binary_logloss: 0.16816
# [1499]	valid_0's binary_logloss: 0.16814
# [1500]	valid_0's binary_logloss: 0.168078
# [1501]	valid_0's binary_logloss: 0.168029
# [1502]	valid_0's binary_logloss: 0.168015
# [1503]	valid_0's binary_logloss: 0.168044
# [1504]	valid_0's binary_logloss: 0.168047
# [1505]	valid_0's binary_logloss: 0.16801
# [1506]	valid_0's binary_logloss: 0.168028
# [1507]	valid_0's binary_logloss: 0.168008
# [1508]	valid_0's binary_logloss: 0.167952
# [1509]	valid_0's binary_logloss: 0.167879
# [1510]	valid_0's binary_logloss: 0.167859
# [1511]	valid_0's binary_logloss: 0.167812
# [1512]	valid_0's binary_logloss: 0.16774
# [1513]	valid_0's binary_logloss: 0.167632
# [1514]	valid_0's binary_logloss: 0.167659
# [1515]	valid_0's binary_logloss: 0.167641
# [1516]	valid_0's binary_logloss: 0.167622
# [1517]	valid_0's binary_logloss: 0.167561
# [1518]	valid_0's binary_logloss: 0.167531
# [1519]	valid_0's binary_logloss: 0.167484
# [1520]	valid_0's binary_logloss: 0.167467
# [1521]	valid_0's binary_logloss: 0.167398
# [1522]	valid_0's binary_logloss: 0.167326
# [1523]	valid_0's binary_logloss: 0.167296
# [1524]	valid_0's binary_logloss: 0.16725
# [1525]	valid_0's binary_logloss: 0.167281
# [1526]	valid_0's binary_logloss: 0.167283
# [1527]	valid_0's binary_logloss: 0.167216
# [1528]	valid_0's binary_logloss: 0.16715
# [1529]	valid_0's binary_logloss: 0.167181
# [1530]	valid_0's binary_logloss: 0.167177
# [1531]	valid_0's binary_logloss: 0.167112
# [1532]	valid_0's binary_logloss: 0.167135
# [1533]	valid_0's binary_logloss: 0.167166
# [1534]	valid_0's binary_logloss: 0.167147
# [1535]	valid_0's binary_logloss: 0.167083
# [1536]	valid_0's binary_logloss: 0.167107
# [1537]	valid_0's binary_logloss: 0.167082
# [1538]	valid_0's binary_logloss: 0.167087
# [1539]	valid_0's binary_logloss: 0.167112
# [1540]	valid_0's binary_logloss: 0.167136
# [1541]	valid_0's binary_logloss: 0.167106
# [1542]	valid_0's binary_logloss: 0.167104
# [1543]	valid_0's binary_logloss: 0.167041
# [1544]	valid_0's binary_logloss: 0.167017
# [1545]	valid_0's binary_logloss: 0.167023
# [1546]	valid_0's binary_logloss: 0.167054
# [1547]	valid_0's binary_logloss: 0.167074
# [1548]	valid_0's binary_logloss: 0.167057
# [1549]	valid_0's binary_logloss: 0.166995
# [1550]	valid_0's binary_logloss: 0.166966
# [1551]	valid_0's binary_logloss: 0.166978
# [1552]	valid_0's binary_logloss: 0.166951
# [1553]	valid_0's binary_logloss: 0.166891
# [1554]	valid_0's binary_logloss: 0.166784
# [1555]	valid_0's binary_logloss: 0.16679
# [1556]	valid_0's binary_logloss: 0.166814
# [1557]	valid_0's binary_logloss: 0.166788
# [1558]	valid_0's binary_logloss: 0.166763
# [1559]	valid_0's binary_logloss: 0.166747
# [1560]	valid_0's binary_logloss: 0.16673
# [1561]	valid_0's binary_logloss: 0.166671
# [1562]	valid_0's binary_logloss: 0.166703
# [1563]	valid_0's binary_logloss: 0.166673
# [1564]	valid_0's binary_logloss: 0.166686
# [1565]	valid_0's binary_logloss: 0.166733
# [1566]	valid_0's binary_logloss: 0.166717
# [1567]	valid_0's binary_logloss: 0.166659
# [1568]	valid_0's binary_logloss: 0.166679
# [1569]	valid_0's binary_logloss: 0.166711
# [1570]	valid_0's binary_logloss: 0.166731
# [1571]	valid_0's binary_logloss: 0.166707
# [1572]	valid_0's binary_logloss: 0.16665
# [1573]	valid_0's binary_logloss: 0.166657
# [1574]	valid_0's binary_logloss: 0.166677
# [1575]	valid_0's binary_logloss: 0.166648
# [1576]	valid_0's binary_logloss: 0.16658
# [1577]	valid_0's binary_logloss: 0.1666
# [1578]	valid_0's binary_logloss: 0.166532
# [1579]	valid_0's binary_logloss: 0.166553
# [1580]	valid_0's binary_logloss: 0.166527
# [1581]	valid_0's binary_logloss: 0.166501
# [1582]	valid_0's binary_logloss: 0.166503
# [1583]	valid_0's binary_logloss: 0.166437
# [1584]	valid_0's binary_logloss: 0.166458
# [1585]	valid_0's binary_logloss: 0.166432
# [1586]	valid_0's binary_logloss: 0.166372
# [1587]	valid_0's binary_logloss: 0.166357
# [1588]	valid_0's binary_logloss: 0.166301
# [1589]	valid_0's binary_logloss: 0.166284
# [1590]	valid_0's binary_logloss: 0.166288
# [1591]	valid_0's binary_logloss: 0.166309
# [1592]	valid_0's binary_logloss: 0.166244
# [1593]	valid_0's binary_logloss: 0.166266
# [1594]	valid_0's binary_logloss: 0.166202
# [1595]	valid_0's binary_logloss: 0.166224
# [1596]	valid_0's binary_logloss: 0.166177
# [1597]	valid_0's binary_logloss: 0.166151
# [1598]	valid_0's binary_logloss: 0.166088
# [1599]	valid_0's binary_logloss: 0.16611
# [1600]	valid_0's binary_logloss: 0.166064
# [1601]	valid_0's binary_logloss: 0.166047
# [1602]	valid_0's binary_logloss: 0.166017
# [1603]	valid_0's binary_logloss: 0.166039
# [1604]	valid_0's binary_logloss: 0.166022
# [1605]	valid_0's binary_logloss: 0.165992
# [1606]	valid_0's binary_logloss: 0.166015
# [1607]	valid_0's binary_logloss: 0.166037
# [1608]	valid_0's binary_logloss: 0.165991
# [1609]	valid_0's binary_logloss: 0.165936
# [1610]	valid_0's binary_logloss: 0.165912
# [1611]	valid_0's binary_logloss: 0.165912
# [1612]	valid_0's binary_logloss: 0.165897
# [1613]	valid_0's binary_logloss: 0.165892
# [1614]	valid_0's binary_logloss: 0.165915
# [1615]	valid_0's binary_logloss: 0.165853
# [1616]	valid_0's binary_logloss: 0.165876
# [1617]	valid_0's binary_logloss: 0.165831
# [1618]	valid_0's binary_logloss: 0.165764
# [1619]	valid_0's binary_logloss: 0.16581
# [1620]	valid_0's binary_logloss: 0.165786
# [1621]	valid_0's binary_logloss: 0.165749
# [1622]	valid_0's binary_logloss: 0.165726
# [1623]	valid_0's binary_logloss: 0.165737
# [1624]	valid_0's binary_logloss: 0.165737
# [1625]	valid_0's binary_logloss: 0.165751
# [1626]	valid_0's binary_logloss: 0.165774
# [1627]	valid_0's binary_logloss: 0.165708
# [1628]	valid_0's binary_logloss: 0.16565
# [1629]	valid_0's binary_logloss: 0.16571
# [1630]	valid_0's binary_logloss: 0.165666
# [1631]	valid_0's binary_logloss: 0.165678
# [1632]	valid_0's binary_logloss: 0.165702
# [1633]	valid_0's binary_logloss: 0.165637
# [1634]	valid_0's binary_logloss: 0.165579
# [1635]	valid_0's binary_logloss: 0.165522
# [1636]	valid_0's binary_logloss: 0.165431
# [1637]	valid_0's binary_logloss: 0.165456
# [1638]	valid_0's binary_logloss: 0.165412
# [1639]	valid_0's binary_logloss: 0.165357
# [1640]	valid_0's binary_logloss: 0.165355
# [1641]	valid_0's binary_logloss: 0.16536
# [1642]	valid_0's binary_logloss: 0.16542
# [1643]	valid_0's binary_logloss: 0.165381
# [1644]	valid_0's binary_logloss: 0.165347
# [1645]	valid_0's binary_logloss: 0.16529
# [1646]	valid_0's binary_logloss: 0.16525
# [1647]	valid_0's binary_logloss: 0.165275
# [1648]	valid_0's binary_logloss: 0.165212
# [1649]	valid_0's binary_logloss: 0.16524
# [1650]	valid_0's binary_logloss: 0.165188
# [1651]	valid_0's binary_logloss: 0.165214
# [1652]	valid_0's binary_logloss: 0.16517
# [1653]	valid_0's binary_logloss: 0.165175
# [1654]	valid_0's binary_logloss: 0.16521
# [1655]	valid_0's binary_logloss: 0.16516
# [1656]	valid_0's binary_logloss: 0.165185
# [1657]	valid_0's binary_logloss: 0.165153
# [1658]	valid_0's binary_logloss: 0.165115
# [1659]	valid_0's binary_logloss: 0.165083
# [1660]	valid_0's binary_logloss: 0.16504
# [1661]	valid_0's binary_logloss: 0.164999
# [1662]	valid_0's binary_logloss: 0.164938
# [1663]	valid_0's binary_logloss: 0.164918
# [1664]	valid_0's binary_logloss: 0.164898
# [1665]	valid_0's binary_logloss: 0.164926
# [1666]	valid_0's binary_logloss: 0.164952
# [1667]	valid_0's binary_logloss: 0.164892
# [1668]	valid_0's binary_logloss: 0.164843
# [1669]	valid_0's binary_logloss: 0.164869
# [1670]	valid_0's binary_logloss: 0.164821
# [1671]	valid_0's binary_logloss: 0.164797
# [1672]	valid_0's binary_logloss: 0.164809
# [1673]	valid_0's binary_logloss: 0.164839
# [1674]	valid_0's binary_logloss: 0.164865
# [1675]	valid_0's binary_logloss: 0.164817
# [1676]	valid_0's binary_logloss: 0.164844
# [1677]	valid_0's binary_logloss: 0.16482
# [1678]	valid_0's binary_logloss: 0.164793
# [1679]	valid_0's binary_logloss: 0.164756
# [1680]	valid_0's binary_logloss: 0.164716
# [1681]	valid_0's binary_logloss: 0.164697
# [1682]	valid_0's binary_logloss: 0.164658
# [1683]	valid_0's binary_logloss: 0.164622
# [1684]	valid_0's binary_logloss: 0.164602
# [1685]	valid_0's binary_logloss: 0.164577
# [1686]	valid_0's binary_logloss: 0.164559
# [1687]	valid_0's binary_logloss: 0.164523
# [1688]	valid_0's binary_logloss: 0.164485
# [1689]	valid_0's binary_logloss: 0.164458
# [1690]	valid_0's binary_logloss: 0.16444
# [1691]	valid_0's binary_logloss: 0.164404
# [1692]	valid_0's binary_logloss: 0.164368
# [1693]	valid_0's binary_logloss: 0.164345
# [1694]	valid_0's binary_logloss: 0.164308
# [1695]	valid_0's binary_logloss: 0.16429
# [1696]	valid_0's binary_logloss: 0.164337
# [1697]	valid_0's binary_logloss: 0.164343
# [1698]	valid_0's binary_logloss: 0.164352
# [1699]	valid_0's binary_logloss: 0.164379
# [1700]	valid_0's binary_logloss: 0.164358
# [1701]	valid_0's binary_logloss: 0.16434
# [1702]	valid_0's binary_logloss: 0.164306
# [1703]	valid_0's binary_logloss: 0.164272
# [1704]	valid_0's binary_logloss: 0.164238
# [1705]	valid_0's binary_logloss: 0.164242
# [1706]	valid_0's binary_logloss: 0.164217
# [1707]	valid_0's binary_logloss: 0.1642
# [1708]	valid_0's binary_logloss: 0.164167
# [1709]	valid_0's binary_logloss: 0.164134
# [1710]	valid_0's binary_logloss: 0.164133
# [1711]	valid_0's binary_logloss: 0.164112
# [1712]	valid_0's binary_logloss: 0.164048
# [1713]	valid_0's binary_logloss: 0.164015
# [1714]	valid_0's binary_logloss: 0.164042
# [1715]	valid_0's binary_logloss: 0.163996
# [1716]	valid_0's binary_logloss: 0.163978
# [1717]	valid_0's binary_logloss: 0.163933
# [1718]	valid_0's binary_logloss: 0.163917
# [1719]	valid_0's binary_logloss: 0.16383
# [1720]	valid_0's binary_logloss: 0.163808
# [1721]	valid_0's binary_logloss: 0.163793
# [1722]	valid_0's binary_logloss: 0.163761
# [1723]	valid_0's binary_logloss: 0.16373
# [1724]	valid_0's binary_logloss: 0.163704
# [1725]	valid_0's binary_logloss: 0.163673
# [1726]	valid_0's binary_logloss: 0.163627
# [1727]	valid_0's binary_logloss: 0.163613
# [1728]	valid_0's binary_logloss: 0.163549
# [1729]	valid_0's binary_logloss: 0.163579
# [1730]	valid_0's binary_logloss: 0.163535
# [1731]	valid_0's binary_logloss: 0.163504
# [1732]	valid_0's binary_logloss: 0.163474
# [1733]	valid_0's binary_logloss: 0.163472
# [1734]	valid_0's binary_logloss: 0.163443
# [1735]	valid_0's binary_logloss: 0.163404
# [1736]	valid_0's binary_logloss: 0.163359
# [1737]	valid_0's binary_logloss: 0.163308
# [1738]	valid_0's binary_logloss: 0.163335
# [1739]	valid_0's binary_logloss: 0.163321
# [1740]	valid_0's binary_logloss: 0.163371
# [1741]	valid_0's binary_logloss: 0.163375
# [1742]	valid_0's binary_logloss: 0.163353
# [1743]	valid_0's binary_logloss: 0.16334
# [1744]	valid_0's binary_logloss: 0.16339
# [1745]	valid_0's binary_logloss: 0.163347
# [1746]	valid_0's binary_logloss: 0.163317
# [1747]	valid_0's binary_logloss: 0.163217
# [1748]	valid_0's binary_logloss: 0.163139
# [1749]	valid_0's binary_logloss: 0.163099
# [1750]	valid_0's binary_logloss: 0.16307
# [1751]	valid_0's binary_logloss: 0.163096
# [1752]	valid_0's binary_logloss: 0.163054
# [1753]	valid_0's binary_logloss: 0.163061
# [1754]	valid_0's binary_logloss: 0.162985
# [1755]	valid_0's binary_logloss: 0.162992
# [1756]	valid_0's binary_logloss: 0.162999
# [1757]	valid_0's binary_logloss: 0.162984
# [1758]	valid_0's binary_logloss: 0.16294
# [1759]	valid_0's binary_logloss: 0.162928
# [1760]	valid_0's binary_logloss: 0.162874
# [1761]	valid_0's binary_logloss: 0.162844
# [1762]	valid_0's binary_logloss: 0.162871
# [1763]	valid_0's binary_logloss: 0.162798
# [1764]	valid_0's binary_logloss: 0.162769
# [1765]	valid_0's binary_logloss: 0.162717
# [1766]	valid_0's binary_logloss: 0.162725
# [1767]	valid_0's binary_logloss: 0.162755
# [1768]	valid_0's binary_logloss: 0.16276
# [1769]	valid_0's binary_logloss: 0.16279
# [1770]	valid_0's binary_logloss: 0.162736
# [1771]	valid_0's binary_logloss: 0.162742
# [1772]	valid_0's binary_logloss: 0.162713
# [1773]	valid_0's binary_logloss: 0.162736
# [1774]	valid_0's binary_logloss: 0.162766
# [1775]	valid_0's binary_logloss: 0.162738
# [1776]	valid_0's binary_logloss: 0.162726
# [1777]	valid_0's binary_logloss: 0.162756
# [1778]	valid_0's binary_logloss: 0.162714
# [1779]	valid_0's binary_logloss: 0.162632
# [1780]	valid_0's binary_logloss: 0.16259
# [1781]	valid_0's binary_logloss: 0.162577
# [1782]	valid_0's binary_logloss: 0.162479
# [1783]	valid_0's binary_logloss: 0.162415
# [1784]	valid_0's binary_logloss: 0.162388
# [1785]	valid_0's binary_logloss: 0.162395
# [1786]	valid_0's binary_logloss: 0.162441
# [1787]	valid_0's binary_logloss: 0.162441
# [1788]	valid_0's binary_logloss: 0.162487
# [1789]	valid_0's binary_logloss: 0.16246
# [1790]	valid_0's binary_logloss: 0.16243
# [1791]	valid_0's binary_logloss: 0.16246
# [1792]	valid_0's binary_logloss: 0.162385
# [1793]	valid_0's binary_logloss: 0.162358
# [1794]	valid_0's binary_logloss: 0.1623
# [1795]	valid_0's binary_logloss: 0.162258
# [1796]	valid_0's binary_logloss: 0.162229
# [1797]	valid_0's binary_logloss: 0.162259
# [1798]	valid_0's binary_logloss: 0.162232
# [1799]	valid_0's binary_logloss: 0.162175
# [1800]	valid_0's binary_logloss: 0.162149
# [1801]	valid_0's binary_logloss: 0.16216
# [1802]	valid_0's binary_logloss: 0.162138
# [1803]	valid_0's binary_logloss: 0.162168
# [1804]	valid_0's binary_logloss: 0.162111
# [1805]	valid_0's binary_logloss: 0.162081
# [1806]	valid_0's binary_logloss: 0.16207
# [1807]	valid_0's binary_logloss: 0.162006
# [1808]	valid_0's binary_logloss: 0.162015
# [1809]	valid_0's binary_logloss: 0.162018
# [1810]	valid_0's binary_logloss: 0.162063
# [1811]	valid_0's binary_logloss: 0.162037
# [1812]	valid_0's binary_logloss: 0.161927
# [1813]	valid_0's binary_logloss: 0.161972
# [1814]	valid_0's binary_logloss: 0.161915
# [1815]	valid_0's binary_logloss: 0.16189
# [1816]	valid_0's binary_logloss: 0.161817
# [1817]	valid_0's binary_logloss: 0.161793
# [1818]	valid_0's binary_logloss: 0.161745
# [1819]	valid_0's binary_logloss: 0.16179
# [1820]	valid_0's binary_logloss: 0.161743
# [1821]	valid_0's binary_logloss: 0.16172
# [1822]	valid_0's binary_logloss: 0.161674
# [1823]	valid_0's binary_logloss: 0.161627
# [1824]	valid_0's binary_logloss: 0.16162
# [1825]	valid_0's binary_logloss: 0.161669
# [1826]	valid_0's binary_logloss: 0.161624
# [1827]	valid_0's binary_logloss: 0.161599
# [1828]	valid_0's binary_logloss: 0.161593
# [1829]	valid_0's binary_logloss: 0.161547
# [1830]	valid_0's binary_logloss: 0.161501
# [1831]	valid_0's binary_logloss: 0.16155
# [1832]	valid_0's binary_logloss: 0.16153
# [1833]	valid_0's binary_logloss: 0.161559
# [1834]	valid_0's binary_logloss: 0.161535
# [1835]	valid_0's binary_logloss: 0.161489
# [1836]	valid_0's binary_logloss: 0.161469
# [1837]	valid_0's binary_logloss: 0.161445
# [1838]	valid_0's binary_logloss: 0.1614
# [1839]	valid_0's binary_logloss: 0.161444
# [1840]	valid_0's binary_logloss: 0.161399
# [1841]	valid_0's binary_logloss: 0.161393
# [1842]	valid_0's binary_logloss: 0.161358
# [1843]	valid_0's binary_logloss: 0.161313
# [1844]	valid_0's binary_logloss: 0.161331
# [1845]	valid_0's binary_logloss: 0.16135
# [1846]	valid_0's binary_logloss: 0.161362
# [1847]	valid_0's binary_logloss: 0.161374
# [1848]	valid_0's binary_logloss: 0.16135
# [1849]	valid_0's binary_logloss: 0.16138
# [1850]	valid_0's binary_logloss: 0.161287
# [1851]	valid_0's binary_logloss: 0.161244
# [1852]	valid_0's binary_logloss: 0.161288
# [1853]	valid_0's binary_logloss: 0.161291
# [1854]	valid_0's binary_logloss: 0.161249
# [1855]	valid_0's binary_logloss: 0.161298
# [1856]	valid_0's binary_logloss: 0.161294
# [1857]	valid_0's binary_logloss: 0.161275
# [1858]	valid_0's binary_logloss: 0.161258
# [1859]	valid_0's binary_logloss: 0.161277
# [1860]	valid_0's binary_logloss: 0.161287
# [1861]	valid_0's binary_logloss: 0.161245
# [1862]	valid_0's binary_logloss: 0.161295
# [1863]	valid_0's binary_logloss: 0.161254
# [1864]	valid_0's binary_logloss: 0.161302
# [1865]	valid_0's binary_logloss: 0.16121
# [1866]	valid_0's binary_logloss: 0.16123
# [1867]	valid_0's binary_logloss: 0.161234
# [1868]	valid_0's binary_logloss: 0.161218
# [1869]	valid_0's binary_logloss: 0.161178
# [1870]	valid_0's binary_logloss: 0.161208
# [1871]	valid_0's binary_logloss: 0.161231
# [1872]	valid_0's binary_logloss: 0.161211
# [1873]	valid_0's binary_logloss: 0.161155
# [1874]	valid_0's binary_logloss: 0.161159
# [1875]	valid_0's binary_logloss: 0.161119
# [1876]	valid_0's binary_logloss: 0.161149
# [1877]	valid_0's binary_logloss: 0.16111
# [1878]	valid_0's binary_logloss: 0.161071
# [1879]	valid_0's binary_logloss: 0.161093
# [1880]	valid_0's binary_logloss: 0.161135
# [1881]	valid_0's binary_logloss: 0.161119
# [1882]	valid_0's binary_logloss: 0.161081
# [1883]	valid_0's binary_logloss: 0.161111
# [1884]	valid_0's binary_logloss: 0.161093
# [1885]	valid_0's binary_logloss: 0.161092
# [1886]	valid_0's binary_logloss: 0.161124
# [1887]	valid_0's binary_logloss: 0.161129
# [1888]	valid_0's binary_logloss: 0.161093
# [1889]	valid_0's binary_logloss: 0.161115
# [1890]	valid_0's binary_logloss: 0.161114
# [1891]	valid_0's binary_logloss: 0.161141
# [1892]	valid_0's binary_logloss: 0.161083
# [1893]	valid_0's binary_logloss: 0.161113
# [1894]	valid_0's binary_logloss: 0.161097
# [1895]	valid_0's binary_logloss: 0.161039
# [1896]	valid_0's binary_logloss: 0.161072
# [1897]	valid_0's binary_logloss: 0.161143
# [1898]	valid_0's binary_logloss: 0.161082
# [1899]	valid_0's binary_logloss: 0.161088
# [1900]	valid_0's binary_logloss: 0.161073
# [1901]	valid_0's binary_logloss: 0.161069
# [1902]	valid_0's binary_logloss: 0.161033
# [1903]	valid_0's binary_logloss: 0.161063
# [1904]	valid_0's binary_logloss: 0.161058
# [1905]	valid_0's binary_logloss: 0.161053
# [1906]	valid_0's binary_logloss: 0.161058
# [1907]	valid_0's binary_logloss: 0.161054
# [1908]	valid_0's binary_logloss: 0.161061
# [1909]	valid_0's binary_logloss: 0.161066
# [1910]	valid_0's binary_logloss: 0.161038
# [1911]	valid_0's binary_logloss: 0.161046
# [1912]	valid_0's binary_logloss: 0.161051
# [1913]	valid_0's binary_logloss: 0.161055
# [1914]	valid_0's binary_logloss: 0.161059
# [1915]	valid_0's binary_logloss: 0.161064
# [1916]	valid_0's binary_logloss: 0.161046
# [1917]	valid_0's binary_logloss: 0.161046
# [1918]	valid_0's binary_logloss: 0.160997
# [1919]	valid_0's binary_logloss: 0.16103
# [1920]	valid_0's binary_logloss: 0.161035
# [1921]	valid_0's binary_logloss: 0.160986
# [1922]	valid_0's binary_logloss: 0.160992
# [1923]	valid_0's binary_logloss: 0.160997
# [1924]	valid_0's binary_logloss: 0.161003
# [1925]	valid_0's binary_logloss: 0.160984
# [1926]	valid_0's binary_logloss: 0.160991
# [1927]	valid_0's binary_logloss: 0.160973
# [1928]	valid_0's binary_logloss: 0.161007
# [1929]	valid_0's binary_logloss: 0.161019
# [1930]	valid_0's binary_logloss: 0.160971
# [1931]	valid_0's binary_logloss: 0.160964
# [1932]	valid_0's binary_logloss: 0.160963
# [1933]	valid_0's binary_logloss: 0.160969
# [1934]	valid_0's binary_logloss: 0.160959
# [1935]	valid_0's binary_logloss: 0.160964
# [1936]	valid_0's binary_logloss: 0.160947
# [1937]	valid_0's binary_logloss: 0.160953
# [1938]	valid_0's binary_logloss: 0.160939
# [1939]	valid_0's binary_logloss: 0.160891
# [1940]	valid_0's binary_logloss: 0.160932
# [1941]	valid_0's binary_logloss: 0.160915
# [1942]	valid_0's binary_logloss: 0.16092
# [1943]	valid_0's binary_logloss: 0.160919
# [1944]	valid_0's binary_logloss: 0.160924
# [1945]	valid_0's binary_logloss: 0.160907
# [1946]	valid_0's binary_logloss: 0.160914
# [1947]	valid_0's binary_logloss: 0.160907
# [1948]	valid_0's binary_logloss: 0.16094
# [1949]	valid_0's binary_logloss: 0.160927
# [1950]	valid_0's binary_logloss: 0.160944
# [1951]	valid_0's binary_logloss: 0.160949
# [1952]	valid_0's binary_logloss: 0.160957
# [1953]	valid_0's binary_logloss: 0.160964
# [1954]	valid_0's binary_logloss: 0.160969
# [1955]	valid_0's binary_logloss: 0.160975
# [1956]	valid_0's binary_logloss: 0.16098
# [1957]	valid_0's binary_logloss: 0.160964
# [1958]	valid_0's binary_logloss: 0.160917
# [1959]	valid_0's binary_logloss: 0.160958
# [1960]	valid_0's binary_logloss: 0.160963
# [1961]	valid_0's binary_logloss: 0.160936
# [1962]	valid_0's binary_logloss: 0.16097
# [1963]	valid_0's binary_logloss: 0.160924
# [1964]	valid_0's binary_logloss: 0.160917
# [1965]	valid_0's binary_logloss: 0.160904
# [1966]	valid_0's binary_logloss: 0.160896
# [1967]	valid_0's binary_logloss: 0.160901
# [1968]	valid_0's binary_logloss: 0.160886
# [1969]	valid_0's binary_logloss: 0.16084
# [1970]	valid_0's binary_logloss: 0.160827
# [1971]	valid_0's binary_logloss: 0.160821
# [1972]	valid_0's binary_logloss: 0.160834
# [1973]	valid_0's binary_logloss: 0.160838
# [1974]	valid_0's binary_logloss: 0.160822
# [1975]	valid_0's binary_logloss: 0.160827
# [1976]	valid_0's binary_logloss: 0.160816
# [1977]	valid_0's binary_logloss: 0.160804
# [1978]	valid_0's binary_logloss: 0.160818
# [1979]	valid_0's binary_logloss: 0.160824
# [1980]	valid_0's binary_logloss: 0.160829
# [1981]	valid_0's binary_logloss: 0.160769
# [1982]	valid_0's binary_logloss: 0.160772
# [1983]	valid_0's binary_logloss: 0.160803
# [1984]	valid_0's binary_logloss: 0.160776
# [1985]	valid_0's binary_logloss: 0.160791
# [1986]	valid_0's binary_logloss: 0.160715
# [1987]	valid_0's binary_logloss: 0.160719
# [1988]	valid_0's binary_logloss: 0.160754
# [1989]	valid_0's binary_logloss: 0.160728
# [1990]	valid_0's binary_logloss: 0.160683
# [1991]	valid_0's binary_logloss: 0.16069
# [1992]	valid_0's binary_logloss: 0.160647
# [1993]	valid_0's binary_logloss: 0.160649
# [1994]	valid_0's binary_logloss: 0.160652
# [1995]	valid_0's binary_logloss: 0.160625
# [1996]	valid_0's binary_logloss: 0.160617
# [1997]	valid_0's binary_logloss: 0.160591
# [1998]	valid_0's binary_logloss: 0.160571
# [1999]	valid_0's binary_logloss: 0.160544
# [2000]	valid_0's binary_logloss: 0.160567
# [2001]	valid_0's binary_logloss: 0.160556
# [2002]	valid_0's binary_logloss: 0.160514
# [2003]	valid_0's binary_logloss: 0.160518
# [2004]	valid_0's binary_logloss: 0.160474
# [2005]	valid_0's binary_logloss: 0.160432
# [2006]	valid_0's binary_logloss: 0.160424
# [2007]	valid_0's binary_logloss: 0.160394
# [2008]	valid_0's binary_logloss: 0.160397
# [2009]	valid_0's binary_logloss: 0.160406
# [2010]	valid_0's binary_logloss: 0.160374
# [2011]	valid_0's binary_logloss: 0.160332
# [2012]	valid_0's binary_logloss: 0.160335
# [2013]	valid_0's binary_logloss: 0.1603
# [2014]	valid_0's binary_logloss: 0.16031
# [2015]	valid_0's binary_logloss: 0.160263
# [2016]	valid_0's binary_logloss: 0.160252
# [2017]	valid_0's binary_logloss: 0.160211
# [2018]	valid_0's binary_logloss: 0.160187
# [2019]	valid_0's binary_logloss: 0.160213
# [2020]	valid_0's binary_logloss: 0.160216
# [2021]	valid_0's binary_logloss: 0.160205
# [2022]	valid_0's binary_logloss: 0.160165
# [2023]	valid_0's binary_logloss: 0.160157
# [2024]	valid_0's binary_logloss: 0.160159
# [2025]	valid_0's binary_logloss: 0.160165
# [2026]	valid_0's binary_logloss: 0.160118
# [2027]	valid_0's binary_logloss: 0.160095
# [2028]	valid_0's binary_logloss: 0.160015
# [2029]	valid_0's binary_logloss: 0.159991
# [2030]	valid_0's binary_logloss: 0.159983
# [2031]	valid_0's binary_logloss: 0.159942
# [2032]	valid_0's binary_logloss: 0.159948
# [2033]	valid_0's binary_logloss: 0.159948
# [2034]	valid_0's binary_logloss: 0.159951
# [2035]	valid_0's binary_logloss: 0.159933
# [2036]	valid_0's binary_logloss: 0.159939
# [2037]	valid_0's binary_logloss: 0.16001
# [2038]	valid_0's binary_logloss: 0.159992
# [2039]	valid_0's binary_logloss: 0.159997
# [2040]	valid_0's binary_logloss: 0.159985
# [2041]	valid_0's binary_logloss: 0.159985
# [2042]	valid_0's binary_logloss: 0.159977
# [2043]	valid_0's binary_logloss: 0.159981
# [2044]	valid_0's binary_logloss: 0.159905
# [2045]	valid_0's binary_logloss: 0.159865
# [2046]	valid_0's binary_logloss: 0.159849
# [2047]	valid_0's binary_logloss: 0.15992
# [2048]	valid_0's binary_logloss: 0.159926
# [2049]	valid_0's binary_logloss: 0.159902
# [2050]	valid_0's binary_logloss: 0.15993
# [2051]	valid_0's binary_logloss: 0.159887
# [2052]	valid_0's binary_logloss: 0.159876
# [2053]	valid_0's binary_logloss: 0.159865
# [2054]	valid_0's binary_logloss: 0.159865
# [2055]	valid_0's binary_logloss: 0.159925
# [2056]	valid_0's binary_logloss: 0.159902
# [2057]	valid_0's binary_logloss: 0.159891
# [2058]	valid_0's binary_logloss: 0.159892
# [2059]	valid_0's binary_logloss: 0.159952
# [2060]	valid_0's binary_logloss: 0.159901
# [2061]	valid_0's binary_logloss: 0.159894
# [2062]	valid_0's binary_logloss: 0.159875
# [2063]	valid_0's binary_logloss: 0.15988
# [2064]	valid_0's binary_logloss: 0.159864
# [2065]	valid_0's binary_logloss: 0.159853
# [2066]	valid_0's binary_logloss: 0.159799
# [2067]	valid_0's binary_logloss: 0.159804
# [2068]	valid_0's binary_logloss: 0.159707
# [2069]	valid_0's binary_logloss: 0.159664
# [2070]	valid_0's binary_logloss: 0.159626
# [2071]	valid_0's binary_logloss: 0.159622
# [2072]	valid_0's binary_logloss: 0.159611
# [2073]	valid_0's binary_logloss: 0.159595
# [2074]	valid_0's binary_logloss: 0.159594
# [2075]	valid_0's binary_logloss: 0.159584
# [2076]	valid_0's binary_logloss: 0.159573
# [2077]	valid_0's binary_logloss: 0.159539
# [2078]	valid_0's binary_logloss: 0.159599
# [2079]	valid_0's binary_logloss: 0.159583
# [2080]	valid_0's binary_logloss: 0.159572
# [2081]	valid_0's binary_logloss: 0.159572
# [2082]	valid_0's binary_logloss: 0.159576
# [2083]	valid_0's binary_logloss: 0.159564
# [2084]	valid_0's binary_logloss: 0.159557
# [2085]	valid_0's binary_logloss: 0.159515
# [2086]	valid_0's binary_logloss: 0.159575
# [2087]	valid_0's binary_logloss: 0.159587
# [2088]	valid_0's binary_logloss: 0.159565
# [2089]	valid_0's binary_logloss: 0.159569
# [2090]	valid_0's binary_logloss: 0.159558
# [2091]	valid_0's binary_logloss: 0.159571
# [2092]	valid_0's binary_logloss: 0.159499
# [2093]	valid_0's binary_logloss: 0.159477
# [2094]	valid_0's binary_logloss: 0.159447
# [2095]	valid_0's binary_logloss: 0.159478
# [2096]	valid_0's binary_logloss: 0.159481
# [2097]	valid_0's binary_logloss: 0.159542
# [2098]	valid_0's binary_logloss: 0.15949
# [2099]	valid_0's binary_logloss: 0.159439
# [2100]	valid_0's binary_logloss: 0.159412
# [2101]	valid_0's binary_logloss: 0.159402
# [2102]	valid_0's binary_logloss: 0.159347
# [2103]	valid_0's binary_logloss: 0.159277
# [2104]	valid_0's binary_logloss: 0.159292
# [2105]	valid_0's binary_logloss: 0.159296
# [2106]	valid_0's binary_logloss: 0.159259
# [2107]	valid_0's binary_logloss: 0.159245
# [2108]	valid_0's binary_logloss: 0.15924
# [2109]	valid_0's binary_logloss: 0.1593
# [2110]	valid_0's binary_logloss: 0.15928
# [2111]	valid_0's binary_logloss: 0.15927
# [2112]	valid_0's binary_logloss: 0.15923
# [2113]	valid_0's binary_logloss: 0.159233
# [2114]	valid_0's binary_logloss: 0.159222
# [2115]	valid_0's binary_logloss: 0.159286
# [2116]	valid_0's binary_logloss: 0.15931
# [2117]	valid_0's binary_logloss: 0.159314
# [2118]	valid_0's binary_logloss: 0.159328
# [2119]	valid_0's binary_logloss: 0.159279
# [2120]	valid_0's binary_logloss: 0.159211
# [2121]	valid_0's binary_logloss: 0.159199
# [2122]	valid_0's binary_logloss: 0.159195
# [2123]	valid_0's binary_logloss: 0.159188
# [2124]	valid_0's binary_logloss: 0.159176
# [2125]	valid_0's binary_logloss: 0.159101
# [2126]	valid_0's binary_logloss: 0.159081
# [2127]	valid_0's binary_logloss: 0.159047
# [2128]	valid_0's binary_logloss: 0.159032
# [2129]	valid_0's binary_logloss: 0.159015
# [2130]	valid_0's binary_logloss: 0.158944
# [2131]	valid_0's binary_logloss: 0.158904
# [2132]	valid_0's binary_logloss: 0.158894
# [2133]	valid_0's binary_logloss: 0.158864
# [2134]	valid_0's binary_logloss: 0.158867
# [2135]	valid_0's binary_logloss: 0.158856
# [2136]	valid_0's binary_logloss: 0.158822
# [2137]	valid_0's binary_logloss: 0.158876
# [2138]	valid_0's binary_logloss: 0.158842
# [2139]	valid_0's binary_logloss: 0.158811
# [2140]	valid_0's binary_logloss: 0.158806
# [2141]	valid_0's binary_logloss: 0.15882
# [2142]	valid_0's binary_logloss: 0.158774
# [2143]	valid_0's binary_logloss: 0.158766
# [2144]	valid_0's binary_logloss: 0.158754
# [2145]	valid_0's binary_logloss: 0.158772
# [2146]	valid_0's binary_logloss: 0.158774
# [2147]	valid_0's binary_logloss: 0.158743
# [2148]	valid_0's binary_logloss: 0.158684
# [2149]	valid_0's binary_logloss: 0.158648
# [2150]	valid_0's binary_logloss: 0.158613
# [2151]	valid_0's binary_logloss: 0.158604
# [2152]	valid_0's binary_logloss: 0.158594
# [2153]	valid_0's binary_logloss: 0.158595
# [2154]	valid_0's binary_logloss: 0.158585
# [2155]	valid_0's binary_logloss: 0.158527
# [2156]	valid_0's binary_logloss: 0.158541
# [2157]	valid_0's binary_logloss: 0.158531
# [2158]	valid_0's binary_logloss: 0.158562
# [2159]	valid_0's binary_logloss: 0.158552
# [2160]	valid_0's binary_logloss: 0.158556
# [2161]	valid_0's binary_logloss: 0.15856
# [2162]	valid_0's binary_logloss: 0.158613
# [2163]	valid_0's binary_logloss: 0.158582
# [2164]	valid_0's binary_logloss: 0.158553
# [2165]	valid_0's binary_logloss: 0.158479
# [2166]	valid_0's binary_logloss: 0.158439
# [2167]	valid_0's binary_logloss: 0.15842
# [2168]	valid_0's binary_logloss: 0.15839
# [2169]	valid_0's binary_logloss: 0.158378
# [2170]	valid_0's binary_logloss: 0.158377
# [2171]	valid_0's binary_logloss: 0.158351
# [2172]	valid_0's binary_logloss: 0.158342
# [2173]	valid_0's binary_logloss: 0.158346
# [2174]	valid_0's binary_logloss: 0.15837
# [2175]	valid_0's binary_logloss: 0.158393
# [2176]	valid_0's binary_logloss: 0.158384
# [2177]	valid_0's binary_logloss: 0.158328
# [2178]	valid_0's binary_logloss: 0.158334
# [2179]	valid_0's binary_logloss: 0.158313
# [2180]	valid_0's binary_logloss: 0.158305
# [2181]	valid_0's binary_logloss: 0.158312
# [2182]	valid_0's binary_logloss: 0.158299
# [2183]	valid_0's binary_logloss: 0.158304
# [2184]	valid_0's binary_logloss: 0.158292
# [2185]	valid_0's binary_logloss: 0.158263
# [2186]	valid_0's binary_logloss: 0.158255
# [2187]	valid_0's binary_logloss: 0.158264
# [2188]	valid_0's binary_logloss: 0.158295
# [2189]	valid_0's binary_logloss: 0.158275
# [2190]	valid_0's binary_logloss: 0.15828
# [2191]	valid_0's binary_logloss: 0.158268
# [2192]	valid_0's binary_logloss: 0.15824
# [2193]	valid_0's binary_logloss: 0.158198
# [2194]	valid_0's binary_logloss: 0.158204
# [2195]	valid_0's binary_logloss: 0.158258
# [2196]	valid_0's binary_logloss: 0.158247
# [2197]	valid_0's binary_logloss: 0.15824
# [2198]	valid_0's binary_logloss: 0.158198
# [2199]	valid_0's binary_logloss: 0.158206
# [2200]	valid_0's binary_logloss: 0.158191
# [2201]	valid_0's binary_logloss: 0.158196
# [2202]	valid_0's binary_logloss: 0.158198
# [2203]	valid_0's binary_logloss: 0.15821
# [2204]	valid_0's binary_logloss: 0.158202
# [2205]	valid_0's binary_logloss: 0.15821
# [2206]	valid_0's binary_logloss: 0.158215
# [2207]	valid_0's binary_logloss: 0.158247
# [2208]	valid_0's binary_logloss: 0.158223
# [2209]	valid_0's binary_logloss: 0.158217
# [2210]	valid_0's binary_logloss: 0.158176
# [2211]	valid_0's binary_logloss: 0.158147
# [2212]	valid_0's binary_logloss: 0.158155
# [2213]	valid_0's binary_logloss: 0.158114
# [2214]	valid_0's binary_logloss: 0.158174
# [2215]	valid_0's binary_logloss: 0.158126
# [2216]	valid_0's binary_logloss: 0.158128
# [2217]	valid_0's binary_logloss: 0.158113
# [2218]	valid_0's binary_logloss: 0.158105
# [2219]	valid_0's binary_logloss: 0.158097
# [2220]	valid_0's binary_logloss: 0.158101
# [2221]	valid_0's binary_logloss: 0.158095
# [2222]	valid_0's binary_logloss: 0.158107
# [2223]	valid_0's binary_logloss: 0.158116
# [2224]	valid_0's binary_logloss: 0.158121
# [2225]	valid_0's binary_logloss: 0.158146
# [2226]	valid_0's binary_logloss: 0.158153
# [2227]	valid_0's binary_logloss: 0.158112
# [2228]	valid_0's binary_logloss: 0.158112
# [2229]	valid_0's binary_logloss: 0.158105
# [2230]	valid_0's binary_logloss: 0.158132
# [2231]	valid_0's binary_logloss: 0.158147
# [2232]	valid_0's binary_logloss: 0.158153
# [2233]	valid_0's binary_logloss: 0.158158
# [2234]	valid_0's binary_logloss: 0.158197
# [2235]	valid_0's binary_logloss: 0.158202
# [2236]	valid_0's binary_logloss: 0.158199
# [2237]	valid_0's binary_logloss: 0.158238
# [2238]	valid_0's binary_logloss: 0.158213
# [2239]	valid_0's binary_logloss: 0.158204
# [2240]	valid_0's binary_logloss: 0.158177
# [2241]	valid_0's binary_logloss: 0.158184
# [2242]	valid_0's binary_logloss: 0.158217
# [2243]	valid_0's binary_logloss: 0.158211
# [2244]	valid_0's binary_logloss: 0.158271
# [2245]	valid_0's binary_logloss: 0.15823
# [2246]	valid_0's binary_logloss: 0.15823
# [2247]	valid_0's binary_logloss: 0.158225
# [2248]	valid_0's binary_logloss: 0.158264
# [2249]	valid_0's binary_logloss: 0.158271
# [2250]	valid_0's binary_logloss: 0.15826
# [2251]	valid_0's binary_logloss: 0.158258
# [2252]	valid_0's binary_logloss: 0.158244
# [2253]	valid_0's binary_logloss: 0.158238
# [2254]	valid_0's binary_logloss: 0.158275
# [2255]	valid_0's binary_logloss: 0.158315
# [2256]	valid_0's binary_logloss: 0.158319
# [2257]	valid_0's binary_logloss: 0.158313
# [2258]	valid_0's binary_logloss: 0.158312
# [2259]	valid_0's binary_logloss: 0.158319
# [2260]	valid_0's binary_logloss: 0.158309
# [2261]	valid_0's binary_logloss: 0.158303
# [2262]	valid_0's binary_logloss: 0.158263
# [2263]	valid_0's binary_logloss: 0.158315
# [2264]	valid_0's binary_logloss: 0.158287
# [2265]	valid_0's binary_logloss: 0.15826
# [2266]	valid_0's binary_logloss: 0.158256
# [2267]	valid_0's binary_logloss: 0.158263
# [2268]	valid_0's binary_logloss: 0.158251
# [2269]	valid_0's binary_logloss: 0.158237
# [2270]	valid_0's binary_logloss: 0.158274
# [2271]	valid_0's binary_logloss: 0.158297
# [2272]	valid_0's binary_logloss: 0.158256
# [2273]	valid_0's binary_logloss: 0.15827
# [2274]	valid_0's binary_logloss: 0.158274
# ...
# [1085]	valid_0's binary_logloss: 0.221378
# [1086]	valid_0's binary_logloss: 0.22133
# [1087]	valid_0's binary_logloss: 0.221465
# [1088]	valid_0's binary_logloss: 0.221467
# [1089]	valid_0's binary_logloss: 0.221428
# [1090]	valid_0's binary_logloss: 0.221438
# [1091]	valid_0's binary_logloss: 0.221441
# [1092]	valid_0's binary_logloss: 0.221574
# [1093]	valid_0's binary_logloss: 0.221486
# [1094]	valid_0's binary_logloss: 0.221546
# [1095]	valid_0's binary_logloss: 0.221511
# [1096]	valid_0's binary_logloss: 0.221472
# [1097]	valid_0's binary_logloss: 0.221475
# [1098]	valid_0's binary_logloss: 0.221612
# [1099]	valid_0's binary_logloss: 0.221531
# [1100]	valid_0's binary_logloss: 0.221545
# [1101]	valid_0's binary_logloss: 0.221599
# [1102]	valid_0's binary_logloss: 0.22152
# [1103]	valid_0's binary_logloss: 0.221496
# [1104]	valid_0's binary_logloss: 0.221472
# [1105]	valid_0's binary_logloss: 0.221438
# [1106]	valid_0's binary_logloss: 0.221351
# [1107]	valid_0's binary_logloss: 0.221355
# [1108]	valid_0's binary_logloss: 0.221276
# [1109]	valid_0's binary_logloss: 0.221256
# [1110]	valid_0's binary_logloss: 0.221271
# [1111]	valid_0's binary_logloss: 0.221217
# [1112]	valid_0's binary_logloss: 0.221139
# [1113]	valid_0's binary_logloss: 0.221252
# [1114]	valid_0's binary_logloss: 0.22123
# [1115]	valid_0's binary_logloss: 0.221207
# [1116]	valid_0's binary_logloss: 0.221189
# [1117]	valid_0's binary_logloss: 0.221176
# [1118]	valid_0's binary_logloss: 0.2211
# [1119]	valid_0's binary_logloss: 0.221114
# [1120]	valid_0's binary_logloss: 0.221092
# [1121]	valid_0's binary_logloss: 0.22104
# [1122]	valid_0's binary_logloss: 0.220985
# [1123]	valid_0's binary_logloss: 0.220954
# [1124]	valid_0's binary_logloss: 0.220935
# [1125]	valid_0's binary_logloss: 0.220929
# [1126]	valid_0's binary_logloss: 0.220907
# [1127]	valid_0's binary_logloss: 0.220853
# [1128]	valid_0's binary_logloss: 0.220811
# [1129]	valid_0's binary_logloss: 0.220761
# [1130]	valid_0's binary_logloss: 0.220749
# [1131]	valid_0's binary_logloss: 0.220704
# [1132]	valid_0's binary_logloss: 0.220727
# [1133]	valid_0's binary_logloss: 0.220592
# [1134]	valid_0's binary_logloss: 0.220615
# [1135]	valid_0's binary_logloss: 0.220734
# [1136]	valid_0's binary_logloss: 0.220831
# [1137]	valid_0's binary_logloss: 0.220845
# [1138]	valid_0's binary_logloss: 0.221001
# [1139]	valid_0's binary_logloss: 0.220971
# [1140]	valid_0's binary_logloss: 0.220955
# [1141]	valid_0's binary_logloss: 0.220937
# [1142]	valid_0's binary_logloss: 0.220934
# [1143]	valid_0's binary_logloss: 0.220913
# [1144]	valid_0's binary_logloss: 0.220815
# [1145]	valid_0's binary_logloss: 0.220848
# [1146]	valid_0's binary_logloss: 0.22087
# [1147]	valid_0's binary_logloss: 0.220827
# [1148]	valid_0's binary_logloss: 0.220867
# [1149]	valid_0's binary_logloss: 0.220881
# [1150]	valid_0's binary_logloss: 0.220851
# [1151]	valid_0's binary_logloss: 0.22089
# [1152]	valid_0's binary_logloss: 0.220899
# [1153]	valid_0's binary_logloss: 0.221063
# [1154]	valid_0's binary_logloss: 0.22093
# [1155]	valid_0's binary_logloss: 0.220954
# [1156]	valid_0's binary_logloss: 0.220892
# [1157]	valid_0's binary_logloss: 0.22085
# [1158]	valid_0's binary_logloss: 0.220832
# [1159]	valid_0's binary_logloss: 0.220833
# [1160]	valid_0's binary_logloss: 0.220812
# [1161]	valid_0's binary_logloss: 0.220792
# [1162]	valid_0's binary_logloss: 0.220697
# [1163]	valid_0's binary_logloss: 0.220706
# [1164]	valid_0's binary_logloss: 0.220716
# [1165]	valid_0's binary_logloss: 0.220729
# [1166]	valid_0's binary_logloss: 0.220816
# [1167]	valid_0's binary_logloss: 0.220775
# [1168]	valid_0's binary_logloss: 0.220756
# [1169]	valid_0's binary_logloss: 0.220746
# [1170]	valid_0's binary_logloss: 0.220732
# [1171]	valid_0's binary_logloss: 0.220772
# [1172]	valid_0's binary_logloss: 0.220733
# [1173]	valid_0's binary_logloss: 0.220674
# [1174]	valid_0's binary_logloss: 0.220663
# [1175]	valid_0's binary_logloss: 0.22067
# [1176]	valid_0's binary_logloss: 0.220577
# [1177]	valid_0's binary_logloss: 0.220557
# [1178]	valid_0's binary_logloss: 0.220563
# [1179]	valid_0's binary_logloss: 0.220523
# [1180]	valid_0's binary_logloss: 0.220507
# [1181]	valid_0's binary_logloss: 0.220433
# [1182]	valid_0's binary_logloss: 0.220386
# [1183]	valid_0's binary_logloss: 0.22047
# [1184]	valid_0's binary_logloss: 0.22041
# [1185]	valid_0's binary_logloss: 0.220378
# [1186]	valid_0's binary_logloss: 0.220366
# [1187]	valid_0's binary_logloss: 0.220436
# [1188]	valid_0's binary_logloss: 0.220442
# [1189]	valid_0's binary_logloss: 0.220386
# [1190]	valid_0's binary_logloss: 0.220357
# [1191]	valid_0's binary_logloss: 0.220399
# [1192]	valid_0's binary_logloss: 0.220419
# [1193]	valid_0's binary_logloss: 0.220329
# [1194]	valid_0's binary_logloss: 0.220347
# [1195]	valid_0's binary_logloss: 0.220275
# [1196]	valid_0's binary_logloss: 0.220238
# [1197]	valid_0's binary_logloss: 0.220253
# [1198]	valid_0's binary_logloss: 0.220229
# [1199]	valid_0's binary_logloss: 0.220285
# [1200]	valid_0's binary_logloss: 0.220213
# [1201]	valid_0's binary_logloss: 0.2202
# [1202]	valid_0's binary_logloss: 0.220189
# [1203]	valid_0's binary_logloss: 0.220181
# [1204]	valid_0's binary_logloss: 0.220126
# [1205]	valid_0's binary_logloss: 0.220073
# [1206]	valid_0's binary_logloss: 0.219989
# [1207]	valid_0's binary_logloss: 0.22
# [1208]	valid_0's binary_logloss: 0.220026
# [1209]	valid_0's binary_logloss: 0.220017
# [1210]	valid_0's binary_logloss: 0.220019
# [1211]	valid_0's binary_logloss: 0.220081
# [1212]	valid_0's binary_logloss: 0.220245
# [1213]	valid_0's binary_logloss: 0.220175
# [1214]	valid_0's binary_logloss: 0.220198
# [1215]	valid_0's binary_logloss: 0.220189
# [1216]	valid_0's binary_logloss: 0.220172
# [1217]	valid_0's binary_logloss: 0.220187
# [1218]	valid_0's binary_logloss: 0.220181
# [1219]	valid_0's binary_logloss: 0.220224
# [1220]	valid_0's binary_logloss: 0.220227
# [1221]	valid_0's binary_logloss: 0.220234
# [1222]	valid_0's binary_logloss: 0.22018
# [1223]	valid_0's binary_logloss: 0.220187
# [1224]	valid_0's binary_logloss: 0.220152
# [1225]	valid_0's binary_logloss: 0.220104
# [1226]	valid_0's binary_logloss: 0.220027
# [1227]	valid_0's binary_logloss: 0.220028
# [1228]	valid_0's binary_logloss: 0.220111
# [1229]	valid_0's binary_logloss: 0.220275
# [1230]	valid_0's binary_logloss: 0.220206
# [1231]	valid_0's binary_logloss: 0.220212
# [1232]	valid_0's binary_logloss: 0.220226
# [1233]	valid_0's binary_logloss: 0.220214
# [1234]	valid_0's binary_logloss: 0.220166
# [1235]	valid_0's binary_logloss: 0.220133
# [1236]	valid_0's binary_logloss: 0.220197
# [1237]	valid_0's binary_logloss: 0.220208
# [1238]	valid_0's binary_logloss: 0.220174
# [1239]	valid_0's binary_logloss: 0.220147
# [1240]	valid_0's binary_logloss: 0.220144
# [1241]	valid_0's binary_logloss: 0.220215
# [1242]	valid_0's binary_logloss: 0.220191
# [1243]	valid_0's binary_logloss: 0.220251
# [1244]	valid_0's binary_logloss: 0.220201
# [1245]	valid_0's binary_logloss: 0.22015
# [1246]	valid_0's binary_logloss: 0.220168
# [1247]	valid_0's binary_logloss: 0.220142
# [1248]	valid_0's binary_logloss: 0.220154
# [1249]	valid_0's binary_logloss: 0.220105
# [1250]	valid_0's binary_logloss: 0.220023
# [1251]	valid_0's binary_logloss: 0.220024
# [1252]	valid_0's binary_logloss: 0.220167
# [1253]	valid_0's binary_logloss: 0.220098
# [1254]	valid_0's binary_logloss: 0.220087
# [1255]	valid_0's binary_logloss: 0.2201
# [1256]	valid_0's binary_logloss: 0.220092
# [1257]	valid_0's binary_logloss: 0.220044
# [1258]	valid_0's binary_logloss: 0.220042
# [1259]	valid_0's binary_logloss: 0.219969
# [1260]	valid_0's binary_logloss: 0.21997
# [1261]	valid_0's binary_logloss: 0.220132
# [1262]	valid_0's binary_logloss: 0.22026
# [1263]	valid_0's binary_logloss: 0.220199
# [1264]	valid_0's binary_logloss: 0.220223
# [1265]	valid_0's binary_logloss: 0.2202
# [1266]	valid_0's binary_logloss: 0.220157
# [1267]	valid_0's binary_logloss: 0.220146
# [1268]	valid_0's binary_logloss: 0.220146
# [1269]	valid_0's binary_logloss: 0.220151
# [1270]	valid_0's binary_logloss: 0.220126
# [1271]	valid_0's binary_logloss: 0.220121
# [1272]	valid_0's binary_logloss: 0.220185
# [1273]	valid_0's binary_logloss: 0.220151
# [1274]	valid_0's binary_logloss: 0.220136
# [1275]	valid_0's binary_logloss: 0.220081
# [1276]	valid_0's binary_logloss: 0.220091
# [1277]	valid_0's binary_logloss: 0.22005
# [1278]	valid_0's binary_logloss: 0.220059
# [1279]	valid_0's binary_logloss: 0.220064
# [1280]	valid_0's binary_logloss: 0.219997
# [1281]	valid_0's binary_logloss: 0.220062
# [1282]	valid_0's binary_logloss: 0.22007
# [1283]	valid_0's binary_logloss: 0.220076
# [1284]	valid_0's binary_logloss: 0.220066
# [1285]	valid_0's binary_logloss: 0.219996
# [1286]	valid_0's binary_logloss: 0.219993
# [1287]	valid_0's binary_logloss: 0.219999
# [1288]	valid_0's binary_logloss: 0.220005
# [1289]	valid_0's binary_logloss: 0.220071
# [1290]	valid_0's binary_logloss: 0.220006
# [1291]	valid_0's binary_logloss: 0.220072
# [1292]	valid_0's binary_logloss: 0.220059
# [1293]	valid_0's binary_logloss: 0.219979
# [1294]	valid_0's binary_logloss: 0.21998
# [1295]	valid_0's binary_logloss: 0.219928
# [1296]	valid_0's binary_logloss: 0.219918
# [1297]	valid_0's binary_logloss: 0.219943
# [1298]	valid_0's binary_logloss: 0.21991
# [1299]	valid_0's binary_logloss: 0.219934
# [1300]	valid_0's binary_logloss: 0.219957
# [1301]	valid_0's binary_logloss: 0.219965
# [1302]	valid_0's binary_logloss: 0.219967
# [1303]	valid_0's binary_logloss: 0.219925
# [1304]	valid_0's binary_logloss: 0.219934
# [1305]	valid_0's binary_logloss: 0.219921
# [1306]	valid_0's binary_logloss: 0.219889
# [1307]	valid_0's binary_logloss: 0.21988
# [1308]	valid_0's binary_logloss: 0.219881
# [1309]	valid_0's binary_logloss: 0.219838
# [1310]	valid_0's binary_logloss: 0.219837
# [1311]	valid_0's binary_logloss: 0.219852
# [1312]	valid_0's binary_logloss: 0.219942
# [1313]	valid_0's binary_logloss: 0.21995
# [1314]	valid_0's binary_logloss: 0.219873
# [1315]	valid_0's binary_logloss: 0.219897
# [1316]	valid_0's binary_logloss: 0.219898
# [1317]	valid_0's binary_logloss: 0.219927
# [1318]	valid_0's binary_logloss: 0.220044
# [1319]	valid_0's binary_logloss: 0.220001
# [1320]	valid_0's binary_logloss: 0.220026
# [1321]	valid_0's binary_logloss: 0.220031
# [1322]	valid_0's binary_logloss: 0.220039
# [1323]	valid_0's binary_logloss: 0.220043
# [1324]	valid_0's binary_logloss: 0.220008
# [1325]	valid_0's binary_logloss: 0.220039
# [1326]	valid_0's binary_logloss: 0.220016
# [1327]	valid_0's binary_logloss: 0.220087
# [1328]	valid_0's binary_logloss: 0.220045
# [1329]	valid_0's binary_logloss: 0.220015
# [1330]	valid_0's binary_logloss: 0.220039
# [1331]	valid_0's binary_logloss: 0.220005
# [1332]	valid_0's binary_logloss: 0.220037
# [1333]	valid_0's binary_logloss: 0.220024
# [1334]	valid_0's binary_logloss: 0.220031
# [1335]	valid_0's binary_logloss: 0.220035
# [1336]	valid_0's binary_logloss: 0.220171
# [1337]	valid_0's binary_logloss: 0.220132
# [1338]	valid_0's binary_logloss: 0.220146
# [1339]	valid_0's binary_logloss: 0.220081
# [1340]	valid_0's binary_logloss: 0.220208
# [1341]	valid_0's binary_logloss: 0.220216
# [1342]	valid_0's binary_logloss: 0.220343
# [1343]	valid_0's binary_logloss: 0.220352
# [1344]	valid_0's binary_logloss: 0.220308
# [1345]	valid_0's binary_logloss: 0.220269
# [1346]	valid_0's binary_logloss: 0.220249
# [1347]	valid_0's binary_logloss: 0.220227
# [1348]	valid_0's binary_logloss: 0.220189
# [1349]	valid_0's binary_logloss: 0.22016
# [1350]	valid_0's binary_logloss: 0.220236
# [1351]	valid_0's binary_logloss: 0.220238
# [1352]	valid_0's binary_logloss: 0.220226
# [1353]	valid_0's binary_logloss: 0.220292
# [1354]	valid_0's binary_logloss: 0.220295
# [1355]	valid_0's binary_logloss: 0.220305
# [1356]	valid_0's binary_logloss: 0.220334
# [1357]	valid_0's binary_logloss: 0.220268
# [1358]	valid_0's binary_logloss: 0.220335
# [1359]	valid_0's binary_logloss: 0.220358
# [1360]	valid_0's binary_logloss: 0.220385
# [1361]	valid_0's binary_logloss: 0.22039
# [1362]	valid_0's binary_logloss: 0.220418
# [1363]	valid_0's binary_logloss: 0.220443
# [1364]	valid_0's binary_logloss: 0.220421
# [1365]	valid_0's binary_logloss: 0.220559
# [1366]	valid_0's binary_logloss: 0.220646
# [1367]	valid_0's binary_logloss: 0.220628
# [1368]	valid_0's binary_logloss: 0.220657
# [1369]	valid_0's binary_logloss: 0.220642
# [1370]	valid_0's binary_logloss: 0.220579
# [1371]	valid_0's binary_logloss: 0.220712
# [1372]	valid_0's binary_logloss: 0.220708
# [1373]	valid_0's binary_logloss: 0.220646
# [1374]	valid_0's binary_logloss: 0.22078
# [1375]	valid_0's binary_logloss: 0.220805
# [1376]	valid_0's binary_logloss: 0.220948
# [1377]	valid_0's binary_logloss: 0.220985
# [1378]	valid_0's binary_logloss: 0.220957
# [1379]	valid_0's binary_logloss: 0.22096
# [1380]	valid_0's binary_logloss: 0.220939
# [1381]	valid_0's binary_logloss: 0.220903
# [1382]	valid_0's binary_logloss: 0.220908
# [1383]	valid_0's binary_logloss: 0.220886
# [1384]	valid_0's binary_logloss: 0.220852
# [1385]	valid_0's binary_logloss: 0.220841
# [1386]	valid_0's binary_logloss: 0.220832
# [1387]	valid_0's binary_logloss: 0.22075
# [1388]	valid_0's binary_logloss: 0.220762
# [1389]	valid_0's binary_logloss: 0.220751
# [1390]	valid_0's binary_logloss: 0.220761
# [1391]	valid_0's binary_logloss: 0.220699
# [1392]	valid_0's binary_logloss: 0.220624
# [1393]	valid_0's binary_logloss: 0.220635
# [1394]	valid_0's binary_logloss: 0.220672
# [1395]	valid_0's binary_logloss: 0.220639
# [1396]	valid_0's binary_logloss: 0.220561
# [1397]	valid_0's binary_logloss: 0.220594
# [1398]	valid_0's binary_logloss: 0.220605
# [1399]	valid_0's binary_logloss: 0.220616
# [1400]	valid_0's binary_logloss: 0.220575
# [1401]	valid_0's binary_logloss: 0.220596
# [1402]	valid_0's binary_logloss: 0.220536
# [1403]	valid_0's binary_logloss: 0.220675
# [1404]	valid_0's binary_logloss: 0.220696
# [1405]	valid_0's binary_logloss: 0.220686
# [1406]	valid_0's binary_logloss: 0.220649
# [1407]	valid_0's binary_logloss: 0.220657
# [1408]	valid_0's binary_logloss: 0.220637
# [1409]	valid_0's binary_logloss: 0.220605
# [1410]	valid_0's binary_logloss: 0.220607
# [1411]	valid_0's binary_logloss: 0.220632
# [1412]	valid_0's binary_logloss: 0.220654
# [1413]	valid_0's binary_logloss: 0.220688
# [1414]	valid_0's binary_logloss: 0.22069
# [1415]	valid_0's binary_logloss: 0.220702
# [1416]	valid_0's binary_logloss: 0.220842
# [1417]	valid_0's binary_logloss: 0.220814
# [1418]	valid_0's binary_logloss: 0.22084
# [1419]	valid_0's binary_logloss: 0.220799
# [1420]	valid_0's binary_logloss: 0.220839
# [1421]	valid_0's binary_logloss: 0.220972
# [1422]	valid_0's binary_logloss: 0.220914
# [1423]	valid_0's binary_logloss: 0.220917
# [1424]	valid_0's binary_logloss: 0.220929
# [1425]	valid_0's binary_logloss: 0.221093
# [1426]	valid_0's binary_logloss: 0.221017
# [1427]	valid_0's binary_logloss: 0.221151
# [1428]	valid_0's binary_logloss: 0.221196
# [1429]	valid_0's binary_logloss: 0.221371
# [1430]	valid_0's binary_logloss: 0.221381
# [1431]	valid_0's binary_logloss: 0.22138
# [1432]	valid_0's binary_logloss: 0.221361
# [1433]	valid_0's binary_logloss: 0.221361
# [1434]	valid_0's binary_logloss: 0.221342
# [1435]	valid_0's binary_logloss: 0.22131
# [1436]	valid_0's binary_logloss: 0.221251
# [1437]	valid_0's binary_logloss: 0.221198
# [1438]	valid_0's binary_logloss: 0.221218
# [1439]	valid_0's binary_logloss: 0.221143
# [1440]	valid_0's binary_logloss: 0.221188
# [1441]	valid_0's binary_logloss: 0.221193
# [1442]	valid_0's binary_logloss: 0.221202
# [1443]	valid_0's binary_logloss: 0.221184
# [1444]	valid_0's binary_logloss: 0.221176
# [1445]	valid_0's binary_logloss: 0.221186
# [1446]	valid_0's binary_logloss: 0.221194
# [1447]	valid_0's binary_logloss: 0.221178
# [1448]	valid_0's binary_logloss: 0.221106
# [1449]	valid_0's binary_logloss: 0.22115
# [1450]	valid_0's binary_logloss: 0.221143
# [1451]	valid_0's binary_logloss: 0.221185
# [1452]	valid_0's binary_logloss: 0.221118
# [1453]	valid_0's binary_logloss: 0.221138
# [1454]	valid_0's binary_logloss: 0.221133
# [1455]	valid_0's binary_logloss: 0.221162
# [1456]	valid_0's binary_logloss: 0.221128
# [1457]	valid_0's binary_logloss: 0.22111
# [1458]	valid_0's binary_logloss: 0.221119
# [1459]	valid_0's binary_logloss: 0.221099
# [1460]	valid_0's binary_logloss: 0.221104
# Early stopping, best iteration is:
# [1310]	valid_0's binary_logloss: 0.219837
# Training Log Loss:  0.08644853084241755
# CV Log Loss:  0.2198370942007053
# -----------------------------------
# SGD Log Loss:  0.16512667434235095

# %% [markdown]
# ## Evaluation Matrices

# %% [markdown]
# ### Confusion Matrix

# %%
y_preds = GBM.predict(X_train, num_iteration=GBM.best_iteration)
y_preds=y_preds.round(0).astype(int)
print(y_preds[0])
confusion_matrix(y_train,y_preds)
# Out:
# 1
# array([[295,  27],
#        [  6, 799]])

# %% [markdown]
# ### PR Curve

# %%
preds = pd.concat([y_train,predictionsBasedOnKFolds.loc[:,'prediction']], axis=1)
preds.columns = ['trueLabel','prediction']
predictionsBasedOnKFoldsLogisticBoosting = preds.copy()
precision, recall, thresholds = precision_recall_curve(preds['trueLabel'],preds['prediction'])
average_precision = average_precision_score(preds['trueLabel'],preds['prediction'])

plt.step(recall, precision, color='k', alpha=0.7, where='post')
plt.fill_between(recall, precision, step='post', alpha=0.3, color='k')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('Precision-Recall curve: Average Precision = {0:0.2f}'.format(average_precision))
# Out:
# Text(0.5, 1.0, 'Precision-Recall curve: Average Precision = 0.99')

# %% [markdown]
# ### ROC Curve

# %%
fpr, tpr, thresholds = roc_curve(preds['trueLabel'],preds['prediction'])
areaUnderROC = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='r', lw=2, label='ROC curve')
plt.plot([0, 1], [0, 1], color='k', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic: Area under the curve = {0:0.2f}'.format(areaUnderROC))
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # Overall Comparison
#
# So far we have tested 3 models for a classification problem and test them on the training set. Lets see how good they are with the test data (spared at the very begining).
#
# We will call our models one by one:

# %%
#Logistic Regression:
predictionsTestSetLogisticRegression = pd.DataFrame(data=[],index=y_test.index,columns=[0,1])

predictionsTestSetLogisticRegression.loc[X_test.index,:] = logReg.predict_proba(X_test)
logLossTestSetLogisticRegression = log_loss(y_test, predictionsTestSetLogisticRegression.loc[X_test.index,1])

print('Log loss of LogReg model: ', logLossTestSetLogisticRegression)
# Out:
# Log loss of LogReg model:  0.3795870799441478

# %% [markdown]
# For the training data, it was 0.3697705832835482.

# %%
#SGD:
predictionsTestSetSGD = pd.DataFrame(data=[],index=y_test.index,columns=[0,1])

predictionsTestSetSGD.loc[X_test.index,:] = SGD.predict_proba(X_test)
logLossTestSetSGD = log_loss(y_test, predictionsTestSetSGD.loc[X_test.index,1])

print('Log loss of SGD model: ', logLossTestSetSGD)
# Out:
# Log loss of SGD model:  6.828031431454252

# %% [markdown]
# For the training data, it was 3.711344525121002.

# %%
#RFC:
predictionsTestSetRFC = pd.DataFrame(data=[],index=y_test.index,columns=[0,1])

predictionsTestSetRFC.loc[X_test.index,:] = RFC.predict_proba(X_test)
logLossTestSetRFC = log_loss(y_test, predictionsTestSetRFC.loc[X_test.index,1])

print('Log loss of RFC model: ', logLossTestSetRFC)
# Out:
# Log loss of RFC model:  1.193581334516454

# %% [markdown]
# For the training data, it was 0.6213293194728228.

# %%
#Boosting with LightGBM:
predictionsTestSetGBM = pd.DataFrame(data=[],index=y_test.index,columns=['prediction'])

predictionsTestSetGBM.loc[X_test.index,'prediction'] =GBM.predict(X_test, num_iteration=GBM.best_iteration)
logLossTestSetGBM = log_loss(y_test,predictionsTestSetGBM.loc[X_test.index,'prediction'])

print('Log loss of SGD model: ', logLossTestSetGBM)
# Out:
# Log loss of SGD model:  0.18323968508249483

# %% [markdown]
# For the training data, it was 0.16512667434235095.

# %% [markdown]
# ## Log Loss Analysis
#
# The next question is whether the obtained log loss is reasonable or not. In binary classification (N=2), as in here, worst performance can be estimated from the limiting solution (random guess):
#
# `Logloss = -log(1 / N) = 0.693`
#
# But here we assume that the data is homogeneous. If we look at how the data is distributed, we see that it is as follows:
#
# `
# 1    1073
# `
#
# `
# 0     430
# `
#
# Then the probability would be equal to prevalence:
#
# `
# p(i) = prevalence(i)
# `
#
# So you need to calculate the log loss according to the dataset:
#
# `
# p(i) = 0.7139055222887558
# `
#
# `
# Log loss ~ 0.6
# `
#
# So, it may be a good practice to check first what would be the log loss for your case:
#
# $$Log Loss = -\frac{1}{N_{positive} + N_{negative}}(\sum_{n=1}^{N_{positive}} log(p(y_i)) + \sum_{n=1}^{N_{negative}} log(1-p(y_i)))$$

# %%
#Calculation example
import math
p = 0.8 #= prevalence(i)
N_case = 100 #example case number
N_pos = 100*p
N_neg = 100*(1-p)
log_loss_prevalence = -1/N_case*(math.log(p)*N_pos + math.log(1-p)*N_neg)
log_loss_prevalence
# Out:
# 0.5004024235381879

# %%
#Lets use the function to generate a graph:
import math
def log_loss_cal(p):
  "Return the log loss of the given prevalence"
  N_case = 100 #example case number
  N_pos = 100*p
  N_neg = 100*(1-p)
  log_loss_prevalence = -1/N_case*(math.log(p)*N_pos + math.log(1-p)*N_neg)
  return log_loss_prevalence


losses_example = []
prevalence = []
for i in range(1,20):
    prevalence.append(i*0.05)
    losses_example.append(log_loss_cal(i*0.05))
#............................
#Plotting the results:
# importing the matplotlib
# see https://matplotlib.org/
#............................
import matplotlib.pyplot as plt
plt.plot(prevalence, losses_example,'-',marker='v', color='b',label="Log Loss")
plt.xlabel("Prevalence")
plt.ylabel("Log Loss")
plt.title("Variation of the Random Log Loss with Prevalence")
# Out:
# Text(0.5, 1.0, 'Variation of the Random Log Loss with Prevalence')

# %% [markdown]
# ### Graphical Results

# %%
#Logistic Regression:
preds = pd.concat([y_test,predictionsTestSetLogisticRegression.loc[:,1]], axis=1)
preds.columns = ['trueLabel','prediction']
precision, recall, thresholds = precision_recall_curve(preds['trueLabel'],preds['prediction'])
average_precision = average_precision_score(preds['trueLabel'],preds['prediction'])

plt.step(recall, precision, color='b', alpha=0.7, where='post')
plt.fill_between(recall, precision, step='post', alpha=0.3, color='b')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('Precision-Recall curve: Average Precision = {0:0.2f}'.format(average_precision))
# Out:
# Text(0.5, 1.0, 'Precision-Recall curve: Average Precision = 0.93')

# %%
fpr, tpr, thresholds = roc_curve(preds['trueLabel'],preds['prediction'])
areaUnderROC = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='b', lw=2, label='ROC curve')
plt.plot([0, 1], [0, 1], color='k', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic: Area under the curve = {0:0.2f}'.format(areaUnderROC))
plt.legend(loc="lower right")
plt.show()

# %%
#SGD 
preds = pd.concat([y_test,predictionsTestSetSGD.loc[:,1]], axis=1)
preds.columns = ['trueLabel','prediction']
precision, recall, thresholds = precision_recall_curve(preds['trueLabel'],preds['prediction'])
average_precision = average_precision_score(preds['trueLabel'],preds['prediction'])

plt.step(recall, precision, color='b', alpha=0.7, where='post')
plt.fill_between(recall, precision, step='post', alpha=0.3, color='b')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('Precision-Recall curve: Average Precision = {0:0.2f}'.format(average_precision))
# Out:
# Text(0.5, 1.0, 'Precision-Recall curve: Average Precision = 0.88')

# %%
fpr, tpr, thresholds = roc_curve(preds['trueLabel'],preds['prediction'])
areaUnderROC = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='b', lw=2, label='ROC curve')
plt.plot([0, 1], [0, 1], color='k', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic: Area under the curve = {0:0.2f}'.format(areaUnderROC))
plt.legend(loc="lower right")
plt.show()

# %%
#RFC
preds = pd.concat([y_test,predictionsTestSetRFC.loc[:,1]], axis=1)
preds.columns = ['trueLabel','prediction']
precision, recall, thresholds = precision_recall_curve(preds['trueLabel'],preds['prediction'])
average_precision = average_precision_score(preds['trueLabel'],preds['prediction'])

plt.step(recall, precision, color='b', alpha=0.7, where='post')
plt.fill_between(recall, precision, step='post', alpha=0.3, color='b')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('Precision-Recall curve: Average Precision = {0:0.2f}'.format(average_precision))
# Out:
# Text(0.5, 1.0, 'Precision-Recall curve: Average Precision = 0.95')

# %%
fpr, tpr, thresholds = roc_curve(preds['trueLabel'],preds['prediction'])
areaUnderROC = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='b', lw=2, label='ROC curve')
plt.plot([0, 1], [0, 1], color='k', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic: Area under the curve = {0:0.2f}'.format(areaUnderROC))
plt.legend(loc="lower right")
plt.show()

# %%
#Boosting
preds = pd.concat([y_test,predictionsTestSetGBM.loc[:,'prediction']], axis=1)
preds.columns = ['trueLabel','prediction']
precision, recall, thresholds = precision_recall_curve(preds['trueLabel'],preds['prediction'])
average_precision = average_precision_score(preds['trueLabel'],preds['prediction'])

plt.step(recall, precision, color='b', alpha=0.7, where='post')
plt.fill_between(recall, precision, step='post', alpha=0.3, color='b')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('Precision-Recall curve: Average Precision = {0:0.2f}'.format(average_precision))
# Out:
# Text(0.5, 1.0, 'Precision-Recall curve: Average Precision = 0.99')

# %%
fpr, tpr, thresholds = roc_curve(preds['trueLabel'],preds['prediction'])
areaUnderROC = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='b', lw=2, label='ROC curve')
plt.plot([0, 1], [0, 1], color='k', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic: Area under the curve = {0:0.2f}'.format(areaUnderROC))
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # How can I use the models then?
# Lets call some variables and try to see the model predictions. Lets remember the data strcture and create a new instance:

# %%
data.sample(5)
# Out:
#       frequency  angle_attack  ...  displacement_thickness  sound_pressure
# 948         200          19.7  ...                0.036484         125.974
# 1264       6300           0.0  ...                0.001320         127.730
# 214        6300           0.0  ...                0.002293         118.410
# 1404       2500           8.9  ...                0.012460         119.190
# 1204       1600          17.4  ...                0.017663         126.846
#
# [5 rows x 6 columns]

# %%
# Test Problem:
test_data = [[3600, 12, 0.11, 43, 0.0041]]

#Model Tests
logReg.predict(test_data), SGD.predict(test_data), RFC.predict(test_data), GBM.predict(test_data).round(0).astype(int)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:446: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   "X does not have valid feature names, but"
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:446: UserWarning: X does not have valid feature names, but SGDClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:446: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# (array([0]), array([0]), array([0]), array([0]))

# %% [markdown]
# ## Saving / Loading Models
#
# We have successfully finished our first ML exercise. If you want to save your models for later usage so as not to train again and again, you can do as follows:

# %%
#Saved model name:
import joblib
joblib_file = "LR_pickled.pkl"
joblib.dump(RFC, joblib_file)
# Out:
# ['LR_pickled.pkl']

# %% [markdown]
# But this is not stored on your local machine. To download it locally:

# %%
from google.colab import files
files.download('LR_pickled.pkl')

# %%
#Reloading
RFC_new = joblib.load(joblib_file)
RFC_new
# Out:
# RandomForestClassifier(bootstrap=False, n_estimators=10, n_jobs=-1,
#                        random_state=2021)

# %% [markdown]
# You can see the current CM directory as follows:

# %%
os.listdir('.')
# Out:
# ['.config', 'LR_pickled.pkl', 'sample_data']

# %% [markdown]
# It is also possible to use your google drive for data storage via PyDrive

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

#Authenticate and create the PyDrive client:
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#Upload a file
uploaded = drive.CreateFile({'title': 'LR_pickled.pkl'})
uploaded.SetContentString('Pickled model')
uploaded.Upload()

#The file is uploaded to your google drive!

# %%
#Downloading a file from Google Drive:
downloaded = drive.CreateFile({'id': uploaded.get('id')})
print('Downloaded content "{}"'.format(downloaded.GetContentString()))
# Out:
# Downloaded content "Pickled model"

# %%
os.listdir('.')
# Out:
# ['.config', 'adc.json', 'LR_pickled.pkl', 'sample_data']

# %% [markdown]
# # Self exercises
#
#
#
# 1.   Change the criteria for the noise level and see the outcomes.
# 2.   Play with k-fold parameters. Experience the role of CV approach.
# 3.   Check the scikit-learn library and experiment with another method. Implement it as the 4th alternative approach.
